# %%
import catboost as cb
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from catboost import CatBoostRegressor, Pool
from sklearn.model_selection import cross_val_score
import numpy as np
import pandas as pd

# %%
# Load dataset
df =pd.read_csv("D:/mohammed/UNI/Dynamic Pricing for Used Cars in Jordan/Electric_cars_feature_engineered.csv")

# %%
df.columns
# Out:
# Index(['Condition', 'Car Make', 'is_luxury', 'Model', 'Model_encoded', 'Trim',
#        'Trim_encoded', 'Year', 'car_age', 'car_age_sqrt',
#        'Kilometers Numerical', 'age_km_interaction', 'Body Type',
#        'Number of Seats', 'Fuel', 'Transmission', 'Engine Size (cc)',
#        'Regional Specs', 'Car License', 'Insurance', 'Car Customs',
#        'Body Condition', 'body_condition_encoded', 'Paint',
#        'paint_condition_encoded', 'interior_steering_wheel_controls',
#        'interior_airbags', 'technology_cruise_control',
#        'exterior_rear_sensors', 'exterior_keyless_entry',
#        'technology_tyre_pressure_monitoring', 'exterior_front_sensors',
#        'interior_electric_seat_control', 'technology_traction_control',
#        'technology_voice_control', 'technology_blind_spot_alert',
#        'technology_forward_collision_alert', 'technology_lane_departure_alert',
#        'technology_navigation_system_/_maps', 'Interior_Options_Count',
#        'Interior_Options_Count_cuberoot', 'Exterior_Options_Count',
#        'Exterior_Options_Count_cuberoot', 'Technology_Options_Count',
#        'Technology_Options_Count_cuberoot', 'tech_features_count',
#        'has_advanced_tech', 'Total_Options_Count',
#        'Total_Options_Count_cuberoot', 'weighted_options', 'Battery Capacity',
#        'Battery Range', 'log_price', 'maintenance_score',
#        'excellent_maintenance', 'size_class'],
#       dtype='object')

# %%
df.drop(columns = ['Fuel','Transmission','Engine Size (cc)','tech_features_count', 'Model_encoded','Trim_encoded'],inplace = True)

# %%
# Identify categorical features
cat_features = df.select_dtypes(include=['object']).columns.tolist()

# Convert NaNs in categorical features to string "NaN"
df[cat_features] = df[cat_features].astype(str).fillna("NaN")

# Identify target and features
target_column = "log_price"  # Change if necessary
X = df.drop(columns=[target_column])
y = df[target_column]

# Initialize CatBoostRegressor
model = CatBoostRegressor(
    iterations=500,  # Increased from 26
    learning_rate=0.05,  # Reduced from 0.1
    depth=8,  # Increased from 6
    l2_leaf_reg=3,  # Added regularization
    border_count=128,  # For better splits
    random_strength=1,  # Helps with generalization
    od_wait=50,  # Increased early stopping patience
    od_type="Iter",
    loss_function='RMSE',  # Explicitly set
    eval_metric='RMSE',
    verbose=100,  # To see training progress
    cat_features=cat_features,
    
)

# Perform 10-fold cross-validation
rmse_scores = -cross_val_score(model, X, y, cv=10, scoring="neg_root_mean_squared_error")
mae_scores = -cross_val_score(model, X, y, cv=10, scoring="neg_mean_absolute_error")
r2_scores = cross_val_score(model, X, y, cv=10, scoring="r2")

# Custom accuracy metric based on MAPE
def mean_absolute_percentage_error(y_true, y_pred):
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# Train model to get predictions
model.fit(X, y)
y_pred = model.predict(X)
mape = mean_absolute_percentage_error(y, y_pred)
accuracy = 100 - mape  # Accuracy as (1 - MAPE) * 100

# Print evaluation metrics
print(f"Mean RMSE: {rmse_scores.mean()}")
print(f"Mean MAE: {mae_scores.mean()}")
print(f"Mean R-Squared: {r2_scores.mean()}")
print(f"Accuracy (1 - MAPE): {accuracy:}%")
# Out:
# 0:	learn: 0.5367538	total: 69.3ms	remaining: 34.6s
# 100:	learn: 0.2112693	total: 7.45s	remaining: 29.4s
# 200:	learn: 0.1818450	total: 15.1s	remaining: 22.5s
# 300:	learn: 0.1642879	total: 24s	remaining: 15.9s
# 400:	learn: 0.1446198	total: 31.9s	remaining: 7.89s
# 499:	learn: 0.1265095	total: 40.1s	remaining: 0us
# 0:	learn: 0.5364979	total: 71.2ms	remaining: 35.5s
# 100:	learn: 0.2138092	total: 7.38s	remaining: 29.1s
# 200:	learn: 0.1820372	total: 15.3s	remaining: 22.7s
# 300:	learn: 0.1633566	total: 23.3s	remaining: 15.4s
# 400:	learn: 0.1489806	total: 30.8s	remaining: 7.6s
# 499:	learn: 0.1343137	total: 38.2s	remaining: 0us
# 0:	learn: 0.5359528	total: 69.5ms	remaining: 34.7s
# 100:	learn: 0.2124121	total: 7.21s	remaining: 28.5s
# 200:	learn: 0.1811265	total: 14.3s	remaining: 21.2s
# 300:	learn: 0.1610481	total: 21.9s	remaining: 14.5s
# 400:	learn: 0.1433589	total: 29.1s	remaining: 7.18s
# 499:	learn: 0.1229049	total: 37.1s	remaining: 0us
# 0:	learn: 0.5334266	total: 55.9ms	remaining: 27.9s
# 100:	learn: 0.2159297	total: 6.56s	remaining: 25.9s
# 200:	learn: 0.1897759	total: 13.6s	remaining: 20.3s
# 300:	learn: 0.1741909	total: 21.5s	remaining: 14.2s
# 400:	learn: 0.1534422	total: 29.7s	remaining: 7.33s
# 499:	learn: 0.1341886	total: 37.7s	remaining: 0us
# 0:	learn: 0.5369814	total: 66.5ms	remaining: 33.2s
# 100:	learn: 0.2128050	total: 7.69s	remaining: 30.4s
# 200:	learn: 0.1796024	total: 15.6s	remaining: 23.2s
# 300:	learn: 0.1589967	total: 23.6s	remaining: 15.6s
# 400:	learn: 0.1365774	total: 31.5s	remaining: 7.78s
# 499:	learn: 0.1207479	total: 39.5s	remaining: 0us
# 0:	learn: 0.5309038	total: 54ms	remaining: 27s
# 100:	learn: 0.2067177	total: 7.26s	remaining: 28.7s
# 200:	learn: 0.1764660	total: 15s	remaining: 22.3s
# 300:	learn: 0.1559572	total: 23.1s	remaining: 15.3s
# 400:	learn: 0.1375458	total: 31s	remaining: 7.67s
# 499:	learn: 0.1213944	total: 38.7s	remaining: 0us
# 0:	learn: 0.5315245	total: 70ms	remaining: 35s
# 100:	learn: 0.2174003	total: 7.18s	remaining: 28.4s
# 200:	learn: 0.1845733	total: 14.2s	remaining: 21.2s
# 300:	learn: 0.1601403	total: 22.2s	remaining: 14.7s
# 400:	learn: 0.1407351	total: 30s	remaining: 7.41s
# 499:	learn: 0.1255507	total: 37.7s	remaining: 0us
# 0:	learn: 0.5342572	total: 60.2ms	remaining: 30s
# 100:	learn: 0.2116080	total: 7.48s	remaining: 29.6s
# 200:	learn: 0.1850876	total: 14.7s	remaining: 21.8s
# 300:	learn: 0.1677949	total: 22.5s	remaining: 14.9s
# 400:	learn: 0.1468545	total: 30.4s	remaining: 7.5s
# 499:	learn: 0.1301161	total: 38.2s	remaining: 0us
# 0:	learn: 0.5330024	total: 62ms	remaining: 30.9s
# 100:	learn: 0.2041952	total: 7.54s	remaining: 29.8s
# 200:	learn: 0.1677387	total: 15s	remaining: 22.3s
# 300:	learn: 0.1463638	total: 22.9s	remaining: 15.2s
# 400:	learn: 0.1304102	total: 30.7s	remaining: 7.57s
# 499:	learn: 0.1179334	total: 38.6s	remaining: 0us
# 0:	learn: 0.5345636	total: 65.3ms	remaining: 32.6s
# 100:	learn: 0.2056000	total: 7.56s	remaining: 29.9s
# 200:	learn: 0.1725441	total: 14.9s	remaining: 22.1s
# 300:	learn: 0.1484327	total: 22.9s	remaining: 15.1s
# 400:	learn: 0.1265817	total: 31s	remaining: 7.64s
# 499:	learn: 0.1118209	total: 38.3s	remaining: 0us
# 0:	learn: 0.5367538	total: 53ms	remaining: 26.4s
# 100:	learn: 0.2112693	total: 7.26s	remaining: 28.7s
# 200:	learn: 0.1818450	total: 14.9s	remaining: 22.2s
# 300:	learn: 0.1642879	total: 22.7s	remaining: 15s
# 400:	learn: 0.1446198	total: 30.5s	remaining: 7.53s
# 499:	learn: 0.1265095	total: 38.2s	remaining: 0us
# 0:	learn: 0.5364979	total: 59.6ms	remaining: 29.7s
# 100:	learn: 0.2138092	total: 7.16s	remaining: 28.3s
# 200:	learn: 0.1820372	total: 14.7s	remaining: 21.9s
# 300:	learn: 0.1633566	total: 22.7s	remaining: 15s
# 400:	learn: 0.1489806	total: 30.5s	remaining: 7.54s
# 499:	learn: 0.1343137	total: 38.7s	remaining: 0us
# 0:	learn: 0.5359528	total: 56.3ms	remaining: 28.1s
# 100:	learn: 0.2124121	total: 7.47s	remaining: 29.5s
# 200:	learn: 0.1811265	total: 15.3s	remaining: 22.7s
# 300:	learn: 0.1610481	total: 23.1s	remaining: 15.3s
# 400:	learn: 0.1433589	total: 31.1s	remaining: 7.67s
# 499:	learn: 0.1229049	total: 38.7s	remaining: 0us
# 0:	learn: 0.5334266	total: 58.3ms	remaining: 29.1s
# 100:	learn: 0.2159297	total: 6.91s	remaining: 27.3s
# 200:	learn: 0.1897759	total: 14s	remaining: 20.8s
# 300:	learn: 0.1741909	total: 21.9s	remaining: 14.5s
# 400:	learn: 0.1534422	total: 29.7s	remaining: 7.34s
# 499:	learn: 0.1341886	total: 37.6s	remaining: 0us
# 0:	learn: 0.5369814	total: 80.2ms	remaining: 40s
# 100:	learn: 0.2128050	total: 7.79s	remaining: 30.8s
# 200:	learn: 0.1796024	total: 15.6s	remaining: 23.1s
# 300:	learn: 0.1589967	total: 23.5s	remaining: 15.5s
# 400:	learn: 0.1365774	total: 31.2s	remaining: 7.7s
# 499:	learn: 0.1207479	total: 38.8s	remaining: 0us
# 0:	learn: 0.5309038	total: 64.8ms	remaining: 32.3s
# 100:	learn: 0.2067177	total: 7.13s	remaining: 28.2s
# 200:	learn: 0.1764660	total: 14.4s	remaining: 21.5s
# 300:	learn: 0.1559572	total: 22.4s	remaining: 14.8s
# 400:	learn: 0.1375458	total: 30.4s	remaining: 7.51s
# 499:	learn: 0.1213944	total: 38.1s	remaining: 0us
# 0:	learn: 0.5315245	total: 56.5ms	remaining: 28.2s
# 100:	learn: 0.2174003	total: 7.34s	remaining: 29s
# 200:	learn: 0.1845733	total: 14.5s	remaining: 21.5s
# 300:	learn: 0.1601403	total: 22.4s	remaining: 14.8s
# 400:	learn: 0.1407351	total: 30.4s	remaining: 7.5s
# 499:	learn: 0.1255507	total: 38.2s	remaining: 0us
# 0:	learn: 0.5342572	total: 61.5ms	remaining: 30.7s
# 100:	learn: 0.2116080	total: 6.87s	remaining: 27.1s
# 200:	learn: 0.1850876	total: 14s	remaining: 20.9s
# 300:	learn: 0.1677949	total: 22s	remaining: 14.5s
# 400:	learn: 0.1468545	total: 29.9s	remaining: 7.37s
# 499:	learn: 0.1301161	total: 37.7s	remaining: 0us
# 0:	learn: 0.5330024	total: 59.7ms	remaining: 29.8s
# 100:	learn: 0.2041952	total: 7.65s	remaining: 30.2s
# 200:	learn: 0.1677387	total: 16s	remaining: 23.8s
# 300:	learn: 0.1463638	total: 25.2s	remaining: 16.7s
# 400:	learn: 0.1304102	total: 34.4s	remaining: 8.5s
# 499:	learn: 0.1179334	total: 43.3s	remaining: 0us
# 0:	learn: 0.5345636	total: 73.8ms	remaining: 36.8s
# 100:	learn: 0.2056000	total: 8.38s	remaining: 33.1s
# 200:	learn: 0.1725441	total: 16.2s	remaining: 24.2s
# 300:	learn: 0.1484327	total: 25.1s	remaining: 16.6s
# 400:	learn: 0.1265817	total: 34s	remaining: 8.4s
# 499:	learn: 0.1118209	total: 42.5s	remaining: 0us
# 0:	learn: 0.5367538	total: 68.9ms	remaining: 34.4s
# 100:	learn: 0.2112693	total: 8.14s	remaining: 32.2s
# 200:	learn: 0.1818450	total: 16.9s	remaining: 25.1s
# 300:	learn: 0.1642879	total: 28s	remaining: 18.5s
# 400:	learn: 0.1446198	total: 36.4s	remaining: 8.99s
# 499:	learn: 0.1265095	total: 44.6s	remaining: 0us
# 0:	learn: 0.5364979	total: 56.4ms	remaining: 28.1s
# 100:	learn: 0.2138092	total: 7.52s	remaining: 29.7s
# 200:	learn: 0.1820372	total: 14.8s	remaining: 22s
# 300:	learn: 0.1633566	total: 22.6s	remaining: 15s
# 400:	learn: 0.1489806	total: 30.4s	remaining: 7.49s
# 499:	learn: 0.1343137	total: 38.1s	remaining: 0us
# 0:	learn: 0.5359528	total: 55.6ms	remaining: 27.8s
# 100:	learn: 0.2124121	total: 7.58s	remaining: 30s
# 200:	learn: 0.1811265	total: 15.5s	remaining: 23.1s
# 300:	learn: 0.1610481	total: 23.4s	remaining: 15.5s
# 400:	learn: 0.1433589	total: 31.3s	remaining: 7.74s
# 499:	learn: 0.1229049	total: 39.1s	remaining: 0us
# 0:	learn: 0.5334266	total: 51.1ms	remaining: 25.5s
# 100:	learn: 0.2159297	total: 7.47s	remaining: 29.5s
# 200:	learn: 0.1897759	total: 14.8s	remaining: 22s
# 300:	learn: 0.1741909	total: 22.8s	remaining: 15s
# 400:	learn: 0.1534422	total: 30.7s	remaining: 7.58s
# 499:	learn: 0.1341886	total: 38.8s	remaining: 0us
# 0:	learn: 0.5369814	total: 53ms	remaining: 26.5s
# 100:	learn: 0.2128050	total: 7.59s	remaining: 30s
# 200:	learn: 0.1796024	total: 15.3s	remaining: 22.7s
# 300:	learn: 0.1589967	total: 23.4s	remaining: 15.5s
# 400:	learn: 0.1365774	total: 33.9s	remaining: 8.36s
# 499:	learn: 0.1207479	total: 41.8s	remaining: 0us
# 0:	learn: 0.5309038	total: 57.3ms	remaining: 28.6s
# 100:	learn: 0.2067177	total: 7.25s	remaining: 28.6s
# 200:	learn: 0.1764660	total: 14.8s	remaining: 21.9s
# 300:	learn: 0.1559572	total: 23s	remaining: 15.2s
# 400:	learn: 0.1375458	total: 31s	remaining: 7.66s
# 499:	learn: 0.1213944	total: 38.5s	remaining: 0us
# 0:	learn: 0.5315245	total: 63.5ms	remaining: 31.7s
# 100:	learn: 0.2174003	total: 7.15s	remaining: 28.2s
# 200:	learn: 0.1845733	total: 14s	remaining: 20.8s
# 300:	learn: 0.1601403	total: 21.9s	remaining: 14.5s
# 400:	learn: 0.1407351	total: 30.5s	remaining: 7.54s
# 499:	learn: 0.1255507	total: 38.3s	remaining: 0us
# 0:	learn: 0.5342572	total: 54.7ms	remaining: 27.3s
# 100:	learn: 0.2116080	total: 7.23s	remaining: 28.6s
# 200:	learn: 0.1850876	total: 14.4s	remaining: 21.4s
# 300:	learn: 0.1677949	total: 22s	remaining: 14.5s
# 400:	learn: 0.1468545	total: 30.1s	remaining: 7.43s
# 499:	learn: 0.1301161	total: 38.5s	remaining: 0us
# 0:	learn: 0.5330024	total: 79.1ms	remaining: 39.4s
# 100:	learn: 0.2041952	total: 8.15s	remaining: 32.2s
# 200:	learn: 0.1677387	total: 16.4s	remaining: 24.4s
# 300:	learn: 0.1463638	total: 24.3s	remaining: 16.1s
# 400:	learn: 0.1304102	total: 32.3s	remaining: 7.97s
# 499:	learn: 0.1179334	total: 40.4s	remaining: 0us
# 0:	learn: 0.5345636	total: 62.3ms	remaining: 31.1s
# 100:	learn: 0.2056000	total: 7.6s	remaining: 30s
# 200:	learn: 0.1725441	total: 15s	remaining: 22.2s
# 300:	learn: 0.1484327	total: 23s	remaining: 15.2s
# 400:	learn: 0.1265817	total: 30.9s	remaining: 7.63s
# 499:	learn: 0.1118209	total: 38.4s	remaining: 0us
# 0:	learn: 0.5329831	total: 53.9ms	remaining: 26.9s
# 100:	learn: 0.2065437	total: 7.21s	remaining: 28.5s
# 200:	learn: 0.1741883	total: 14.9s	remaining: 22.1s
# 300:	learn: 0.1532299	total: 23.2s	remaining: 15.3s
# 400:	learn: 0.1366061	total: 31s	remaining: 7.64s
# 499:	learn: 0.1210253	total: 38.6s	remaining: 0us
# Mean RMSE: 0.24101611981394783
# Mean MAE: 0.14970962866265297
# Mean R-Squared: 0.8048475522569131
# Accuracy (1 - MAPE): 98.96934407186703%

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# Get the actual prices (original scale)
if 'price' in df.columns:
    y_true_price = df['price'].values
else:
    y_true_price = np.exp(y)  # Convert from log_price to price

# Get predicted log prices and convert to original scale
y_pred_log = model.predict(X)
y_pred_price = np.exp(y_pred_log)  # Convert predictions back to original scale

# Calculate metrics on original price scale
rmse_price = np.sqrt(mean_squared_error(y_true_price, y_pred_price))
mae_price = mean_absolute_error(y_true_price, y_pred_price)
r2_price = r2_score(y_true_price, y_pred_price)

# Custom MAPE function for original prices
def mean_absolute_percentage_error(y_true, y_pred):
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

mape_price = mean_absolute_percentage_error(y_true_price, y_pred_price)
accuracy_price = 100 - mape_price

# Print evaluation metrics on original price scale
print("\nMetrics on Original Price Scale:")
print(f"RMSE (Price): {rmse_price}")
print(f"MAE (Price): {mae_price}")
print(f"R-Squared (Price): {r2_price}")
print(f"Accuracy (1 - MAPE) (Price): {accuracy_price:.2f}%")

# Keep your existing log-scale metrics for comparison
print("\nMetrics on Log Price Scale:")
print(f"Mean RMSE (log): {rmse_scores.mean()}")
print(f"Mean MAE (log): {mae_scores.mean()}")
print(f"Mean R-Squared (log): {r2_scores.mean()}")
print(f"Accuracy (1 - MAPE) (log): {accuracy:.2f}%")
# Out:
# Metrics on Original Price Scale:
# RMSE (Price): 4113.499473569396
# MAE (Price): 2087.8470832234457
# R-Squared (Price): 0.8828273717415118
# Accuracy (1 - MAPE) (Price): 89.57%
#
# Metrics on Log Price Scale:
# Mean RMSE (log): 0.24101611981394783
# Mean MAE (log): 0.14970962866265297
# Mean R-Squared (log): 0.8048475522569131
# Accuracy (1 - MAPE) (log): 98.97%

# %%
model.save_model("D:/mohammed/UNI/Dynamic Pricing for Used Cars in Jordan/models/electric.cbm",
                             format="cbm",
                             export_parameters=None,
                             pool=None)

# %%
# After training your model
feature_names = model.feature_names_
feature_names
# Out:
# ['Condition',
#  'Car Make',
#  'is_luxury',
#  'Model',
#  'Trim',
#  'Year',
#  'car_age',
#  'car_age_sqrt',
#  'Kilometers Numerical',
#  'age_km_interaction',
#  'Body Type',
#  'Number of Seats',
#  'Regional Specs',
#  'Car License',
#  'Insurance',
#  'Car Customs',
#  'Body Condition',
#  'body_condition_encoded',
#  'Paint',
#  'paint_condition_encoded',
#  'interior_steering_wheel_controls',
#  'interior_airbags',
#  'technology_cruise_control',
#  'exterior_rear_sensors',
#  'exterior_keyless_entry',
#  'technology_tyre_pressure_monitoring',
#  'exterior_front_sensors',
#  'interior_electric_seat_control',
#  'technology_traction_control',
#  'technology_voice_control',
#  'technology_blind_spot_alert',
#  'technology_forward_collision_alert',
#  'technology_lane_departure_alert',
#  'technology_navigation_system_/_maps',
#  'Interior_Options_Count',
#  'Interior_Options_Count_cuberoot',
#  'Exterior_Options_Count',
#  'Exterior_Options_Count_cuberoot',
#  'Technology_Options_Count',
#  'Technology_Options_Count_cuberoot',
#  'has_advanced_tech',
#  'Total_Options_Count',
#  'Total_Options_Count_cuberoot',
#  'weighted_options',
#  'Battery Capacity',
#  'Battery Range',
#  'maintenance_score',
#  'excellent_maintenance',
#  'size_class']

# %%
cat_features
# Out:
# ['Condition',
#  'Car Make',
#  'Model',
#  'Trim',
#  'Body Type',
#  'Regional Specs',
#  'Car License',
#  'Insurance',
#  'Car Customs',
#  'Body Condition',
#  'Paint',
#  'size_class']
