# %% [markdown]
# # Data Preprocessing
# This notebook consists of the following sections
# * About the Dataset
# * Descovering Structure of the Data
# * Data Transformation
# * Data Cleaning
# * Spliting & Exporting Data

# %% [markdown]
# ## About the Dataset

# %% [markdown]
# The Used Cars in the Jordanian Second-Hand Market Dataset is a web-scraped dataset sourced from opensooq.com, an e-commerce platform used across several Middle Eastern countries, including Jordan. It supports both Customer-to-Customer (C2C) and Business-to-Customer (B2C) transactions for various products, including used cars.

# %% [markdown]
# ### Dataset Documentation

# %%
#importing requried lirbraries 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#creating dictionary for storing meta data
doc_df = {
    "URL": {
        "Description": "Link to the car listing(Used as unique identfier).",
        "Value Range / Examples": "Example: 'https://jo.opensooq.com/en/search/257873181'"
    },
    "Scraped_Time": {
        "Description": "The timestamp when the data was scraped.",
        "Value Range / Examples": "Format: 'YYYY-MM-DD HH:MM:SS'"
    },
    "Condition": {
        "Description": "The condition of the car (New/Used).",
        "Value Range / Examples": ["New", "Used"]
    },
    "Car Make": {
        "Description": "The manufacturer of the car.",
        "Value Range / Examples": ["Toyota", "Hyundai", "Ford", "BMW"]
    },
    "Model": {
        "Description": "The specific model of the car.",
        "Value Range / Examples": ["Corolla", "Civic", "Camry", "X5"]
    },
    "Trim": {
        "Description": "The trim level or variant of the car.",
        "Value Range / Examples": ["SE", "Limited", "Sport", "LX"]
    },
    "Year": {
        "Description": "The manufacturing year of the car.",
        "Value Range / Examples": "Older than 1970 - 2025"
    },
    "Kilometers": {
        "Description": "The mileage range of the car.",
        "Value Range / Examples": "0 - 200,000+ km"
    },
    "Body Type": {
        "Description": "The body style of the car.",
        "Value Range / Examples": ["Sedan", "SUV", "Pickup", "Hatchback","Truck",'HatchBack', 'Coupe', 'Bus - Van','Convertible']
    },
    "Number of Seats": {
        "Description": "The number of seats in the car.",
        "Value Range / Examples": ["2 - more than 9"]
    },
    "Fuel": {
        "Description": "The type of fuel the car uses.",
        "Value Range / Examples":  ['Gasoline','Electric', 'Diesel', 'Hybrid', 'Plug-in - Hybrid', 'Mild Hybrid']
    },
    "Transmission": {
        "Description": "The type of transmission.",
        "Value Range / Examples": ["Automatic", "Manual"]
    },
    "Engine Size (cc)": {
        "Description": "The engine capacity in cubic centimeters.",
        "Value Range / Examples": "500 - 7000+ cc"
    },
    "Exterior Color": {
        "Description": "The color of the car's exterior.",
        "Value Range / Examples": ["Black", "White", "Red", "Blue", "etc."]
    },
    "Interior Color": {
        "Description": "The color of the car's interior.",
        "Value Range / Examples": ["Beige", "Black", "Gray", "Brown"]
    },
    "Regional Specs": {
        "Description": "Specifications based on region.",
        "Value Range / Examples":  ['Korean Specs', 'American Specs', 'Japanese Specs' ,'Other Specs','European Specs', 'GCC Specs']
    },
    "Car License": {
        "Description": "Details about the car's licensing status.",
        "Value Range / Examples":  ['Licensed','Not Licensed']
    },
    "Insurance": {
        "Description": "Whether the car has insurance or not.",
        "Value Range / Examples": ['Compulsory Insurance', 'Comprehensive Insurance', 'Not Insured']
    },
    "Car Customs": {
        "Description": "Indicates if the car has cleared customs.",
        "Value Range / Examples": ['With Customs','Without Customs']
    },
    "Body Condition": {
        "Description": "The condition of the car's body.",
        "Value Range / Examples": ['Excellent with no defects', 'Other', 'Good (body only has minor blemishes)', 'Fair (body needs work)', 'Poor (severe body damages)']
    },
    "Paint": {
        "Description": "The condition of the car's paint.",
        "Value Range / Examples": ["Original", "Repainted", "Partial Repaint"]
    },
    "Payment Method": {
        "Description": "The available payment options.",
        "Value Range / Examples": ["Cash", "Installments", 'Cash or Installments']
    },
    "City": {
        "Description": "The city where the car is listed.",
        "Value Range / Examples":  ['Irbid', 'Amman', 'Ajloun', 'Mafraq', 'Zarqa', 'Aqaba', 'Madaba', 'Salt', 'Al Karak','Jerash','Ramtha',"Ma'an",'Tafila','Jordan Valley']
    },
    "Neighborhood": {
        "Description": "The specific area within the city.",
        "Value Range / Examples": ['Al Quds Street', 'Abu Alanda', 'Tabarboor']
    },
    "Category": {
        "Description": "General category of the listing.",
        "Value Range / Examples": ["Cars and Bikes"]
    },
    "Subcategory": {
        "Description": "More specific category.",
        "Value Range / Examples": ["Cars for Sale", "Classic Cars"]
    },
    "Interior Options": {
        "Description": "Features related to the car's interior.",
        "Value Range / Examples": ['Alarm System', 'AUX / USB Input', 'Airbags', 'Electric Windows']
    },
    "Exterior Options": {
        "Description": "Features related to the car's exterior.",
        "Value Range / Examples": ['Daytime Running Lights', 'Spare Tyre', 'Rim Wheels', 'Rear Sensors']
    },
    "Technology Options": {
        "Description": "Technology-related features.",
        "Value Range / Examples": ["Navigation", "360° Camera", "Touch Screen"]
    },
    "Price": {
        "Description": "The listed price of the car, including currency.",
        "Value Range / Examples": "550 - 1000,000 JOD"
    },
    "Description_Score": {
        "Description": "Description or rating of the car's condition.",
        "Value Range / Examples": "4-7 (1 = Poor, 7 = Excellent)"
    },
    "Battery Capacity": {
        "Description": "For electric vehicles, the battery capacity range.",
        "Value Range / Examples": ["less than 50kwh - more than 100,000kwh"]
    },
    "Battery Range": {
        "Description": "The estimated driving range on a full charge.",
        "Value Range / Examples": "less than 100 - more than 500 km"
    }
}
#converting dictionary to table
doc_df = {
    "Column Name": list(doc_df.keys()),
    "Description": [doc_df[col]["Description"] for col in doc_df],
    "Value Range / Examples": [doc_df[col]["Value Range / Examples"] for col in doc_df]
}
#converting 'doc_df' from dictionary to dataframe
doc_df = pd.DataFrame(doc_df)

# %%
#printing out the table
from IPython.display import display
display(doc_df)
# Out:
#            Column Name                                        Description  \
# 0                  URL  Link to the car listing(Used as unique identfi...
# 1         Scraped_Time           The timestamp when the data was scraped.
# 2            Condition               The condition of the car (New/Used).
# 3             Car Make                       The manufacturer of the car.
# 4                Model                     The specific model of the car.
# 5                 Trim              The trim level or variant of the car.
# 6                 Year                 The manufacturing year of the car.
# 7           Kilometers                      The mileage range of the car.
# 8            Body Type                         The body style of the car.
# 9      Number of Seats                    The number of seats in the car.
# 10                Fuel                     The type of fuel the car uses.
# 11        Transmission                          The type of transmission.
# 12    Engine Size (cc)          The engine capacity in cubic centimeters.
# 13      Exterior Color                   The color of the car's exterior.
# 14      Interior Color                   The color of the car's interior.
# 15      Regional Specs                    Specifications based on region.
# 16         Car License          Details about the car's licensing status.
# 17           Insurance              Whether the car has insurance or not.
# 18         Car Customs          Indicates if the car has cleared customs.
# 19      Body Condition                   The condition of the car's body.
# 20               Paint                  The condition of the car's paint.
# 21      Payment Method                     The available payment options.
# 22                City                  The city where the car is listed.
# 23        Neighborhood                 The specific area within the city.
# 24            Category                   General category of the listing.
# 25         Subcategory                            More specific category.
# 26    Interior Options            Features related to the car's interior.
# 27    Exterior Options            Features related to the car's exterior.
# 28  Technology Options                       Technology-related features.
# 29               Price   The listed price of the car, including currency.
# 30   Description_Score      Description or rating of the car's condition.
# 31    Battery Capacity  For electric vehicles, the battery capacity ra...
# 32       Battery Range      The estimated driving range on a full charge.
#
#                                Value Range / Examples
# 0   Example: 'https://jo.opensooq.com/en/search/25...
# 1                       Format: 'YYYY-MM-DD HH:MM:SS'
# 2                                         [New, Used]
# 3                        [Toyota, Hyundai, Ford, BMW]
# 4                         [Corolla, Civic, Camry, X5]
# 5                            [SE, Limited, Sport, LX]
# 6                              Older than 1970 - 2025
# 7                                     0 - 200,000+ km
# 8   [Sedan, SUV, Pickup, Hatchback, Truck, HatchBa...
# 9                                   [2 - more than 9]
# 10  [Gasoline, Electric, Diesel, Hybrid, Plug-in -...
# 11                                [Automatic, Manual]
# 12                                     500 - 7000+ cc
# 13                    [Black, White, Red, Blue, etc.]
# 14                        [Beige, Black, Gray, Brown]
# 15  [Korean Specs, American Specs, Japanese Specs,...
# 16                           [Licensed, Not Licensed]
# 17  [Compulsory Insurance, Comprehensive Insurance...
# 18                    [With Customs, Without Customs]
# 19  [Excellent with no defects, Other, Good (body ...
# 20             [Original, Repainted, Partial Repaint]
# 21         [Cash, Installments, Cash or Installments]
# 22  [Irbid, Amman, Ajloun, Mafraq, Zarqa, Aqaba, M...
# 23            [Al Quds Street, Abu Alanda, Tabarboor]
# 24                                   [Cars and Bikes]
# 25                      [Cars for Sale, Classic Cars]
# 26  [Alarm System, AUX / USB Input, Airbags, Elect...
# 27  [Daytime Running Lights, Spare Tyre, Rim Wheel...
# 28            [Navigation, 360° Camera, Touch Screen]
# 29                                 550 - 1000,000 JOD
# 30                      4-7 (1 = Poor, 7 = Excellent)
# 31           [less than 50kwh - more than 100,000kwh]
# 32                   less than 100 - more than 500 km

# %% [markdown]
# ## Descovering Structure of the Data

# %%
#Changing the view settings of dataframe 
pd.set_option('display.max_rows', None)  # Show all rows
pd.set_option('display.max_columns', None)  # Show all columns

# %%
#reading dataset
df = pd.read_csv("D:/mohammed/UNI/Dynamic Pricing for Used Cars in Jordan/Data/car_data.csv")

# %%
#view a sample of dataset of size 10
df.sample(10)
# Out:
#                                                URL         Scraped_Time  \
# 1519   https://jo.opensooq.com/en/search/258113211  2025-02-06 22:37:03
# 9440   https://jo.opensooq.com/en/search/257564961  2025-02-07 12:56:39
# 1245   https://jo.opensooq.com/en/search/258662917  2025-02-06 22:32:42
# 11461  https://jo.opensooq.com/en/search/257766593  2025-02-07 14:17:51
# 4423   https://jo.opensooq.com/en/search/258366101  2025-02-07 01:45:15
# 10781  https://jo.opensooq.com/en/search/257363989  2025-02-07 13:25:48
# 10218  https://jo.opensooq.com/en/search/257468785  2025-02-07 13:08:13
# 7663   https://jo.opensooq.com/en/search/257935979  2025-02-07 11:14:25
# 6958   https://jo.opensooq.com/en/search/258047731  2025-02-07 11:03:50
# 3382   https://jo.opensooq.com/en/search/258486131  2025-02-07 00:43:38
#
#       Condition    Car Make    Model      Trim  Year         Kilometers  \
# 1519        New        Neta    Other       NaN  2023                  0
# 9440       Used      Nissan     Leaf         S  2013    90,000 - 99,999
# 1245       Used         Kia   Optima        EX  2016    80,000 - 89,999
# 11461      Used        Ford   Fusion        SE  2013           +200,000
# 4423       Used        Opel   Vectra       NaN  1992  160,000 - 169,999
# 10781      Used        Opel   Kadett       NaN  1990           +200,000
# 10218      Used      Toyota    Hilux       GLX  2022      1,000 - 9,999
# 7663       Used  Volkswagen     Bora    E-Bora  2021    40,000 - 49,999
# 6958       Used  Volkswagen  Touareg  Standard  2006  160,000 - 169,999
# 3382       Used       Honda    Civic       LXi  2006           +200,000
#
#        Body Type Number of Seats      Fuel Transmission  Engine Size (cc)  \
# 1519   HatchBack               5  Electric    Automatic               NaN
# 9440   HatchBack               5  Electric    Automatic               NaN
# 1245       Sedan               5    Hybrid    Automatic  2,000 - 2,999 cc
# 11461      Sedan               5    Hybrid    Automatic  2,000 - 2,999 cc
# 4423       Sedan               5  Gasoline       Manual               NaN
# 10781  HatchBack               5  Gasoline       Manual  1,000 - 1,999 cc
# 10218     PickUp               4    Diesel    Automatic  2,000 - 2,999 cc
# 7663       Sedan               5  Electric    Automatic               NaN
# 6958         SUV               5  Gasoline    Automatic  3,000 - 3,999 cc
# 3382       Sedan               5  Gasoline    Automatic        0 - 499 cc
#
#       Exterior Color Interior Color  Regional Specs Car License  \
# 1519           Green          Black     Other Specs    Licensed
# 9440           White          Black  Japanese Specs    Licensed
# 1245           Black          Beige  American Specs    Licensed
# 11461          Brown          Black  American Specs    Licensed
# 4423        Burgundy     Nardo Grey  European Specs    Licensed
# 10781      Navy Blue      Navy Blue  European Specs    Licensed
# 10218          Black            Red       GCC Specs    Licensed
# 7663           White          Black  European Specs    Licensed
# 6958     Olive Green    Olive Green  European Specs    Licensed
# 3382            Blue           Grey  Japanese Specs    Licensed
#
#                   Insurance   Car Customs             Body Condition  \
# 1519   Compulsory Insurance  With Customs                        NaN
# 9440   Compulsory Insurance  With Customs                        NaN
# 1245   Compulsory Insurance  With Customs  Excellent with no defects
# 11461  Compulsory Insurance  With Customs                      Other
# 4423   Compulsory Insurance  With Customs  Excellent with no defects
# 10781  Compulsory Insurance  With Customs  Excellent with no defects
# 10218  Compulsory Insurance  With Customs  Excellent with no defects
# 7663   Compulsory Insurance  With Customs                      Other
# 6958   Compulsory Insurance  With Customs                      Other
# 3382   Compulsory Insurance  With Customs  Excellent with no defects
#
#                      Paint        Payment Method    City  \
# 1519                   NaN  Cash or Installments   Zarqa
# 9440                   NaN             Cash Only   Amman
# 1245        Original Paint  Cash or Installments   Amman
# 11461        Total repaint             Cash Only   Amman
# 4423                 Other             Cash Only  Mafraq
# 10781  Partially repainted             Cash Only   Irbid
# 10218       Original Paint             Cash Only  Jerash
# 7663   Partially repainted             Cash Only   Zarqa
# 6958   Partially repainted             Cash Only   Amman
# 3382                 Other             Cash Only   Amman
#
#                    Neighborhood        Category    Subcategory  \
# 1519        Al mantika Al Hurra  Cars and Bikes  Cars For Sale
# 9440                     Abdoun  Cars and Bikes  Cars For Sale
# 1245                  Tabarboor  Cars and Bikes  Cars For Sale
# 11461                    Dabouq  Cars and Bikes  Cars For Sale
# 4423   Al-Badiah Ash-Shamaliyah  Cars and Bikes  Cars For Sale
# 10781                  Huwwarah  Cars and Bikes  Cars For Sale
# 10218                     Other  Cars and Bikes  Cars For Sale
# 7663        Al mantika Al Hurra  Cars and Bikes  Cars For Sale
# 6958                  Tabarboor  Cars and Bikes  Cars For Sale
# 3382           Jabal Al Hussain  Cars and Bikes  Cars For Sale
#
#                                         Interior Options  \
# 1519   Electric Windows, Center Lock, Leather Seats, ...
# 9440   Heated Seats, CD player, Heated Steering Wheel...
# 1245   Airbags, Alarm System, Steering Wheel Controls...
# 11461  Airbags, Steering Wheel Controls, Electric Sea...
# 4423                                        Heated Seats
# 10781                            Steering Wheel Controls
# 10218  Airbags, Alarm System, Steering Wheel Controls...
# 7663   AUX / USB Input, Airbags, Electric Windows, Ce...
# 6958   Electric Seat Control, Air Condition, Steering...
# 3382   Center Lock, CD player, Air Condition, Alarm S...
#
#                                         Exterior Options  \
# 1519   Keyless Entry, Electrically Folding Mirrors, E...
# 9440   Daytime Running Lights, Keyless Entry, Electri...
# 1245   Electrically Folding Mirrors, Spare Tyre, Elec...
# 11461                                         Rim Wheels
# 4423                                 Spare Tyre, Sunroof
# 10781                             Daytime Running Lights
# 10218  Xenon Lights, Daytime Running Lights, LED Ligh...
# 7663   Rear Sensors, Electric Mirrors, Xenon Lights, ...
# 6958   Back Hook, Daytime Running Lights, Spare Tyre,...
# 3382   Electric Mirrors, Xenon Lights, LED Lights, Da...
#
#                                       Technology Options       Price  \
# 1519   Touch Screen, Media Screen, ABS Brakes, Auto L...  13,250 JOD
# 9440        Traction Control, Media Screen, Touch Screen   5,600 JOD
# 1245   Voice Control, Media Screen, Hud Projector, AB...  13,700 JOD
# 11461  Cruise Control, Bluetooth, Sport Suspension, T...  10,600 JOD
# 4423                                           Bluetooth   2,100 JOD
# 10781                                      Hud Projector   1,600 JOD
# 10218  ABS Brakes, Auto Lock System, Voice Control, R...     999 JOD
# 7663   Tyre Pressure Monitoring, Touch Screen, Media ...  11,600 JOD
# 6958                                           Diff Lock   7,300 JOD
# 3382                                          ABS Brakes   6,500 JOD
#
#       Description_Score  Battery Capacity Battery Range
# 1519                NaN  Less than 50 kWh  400 - 499 km
# 9440                  4       50 - 69 kWh  100 - 199 km
# 1245                  7               NaN           NaN
# 11461                 2               NaN           NaN
# 4423                NaN               NaN           NaN
# 10781               NaN               NaN           NaN
# 10218          فحص كامل               NaN           NaN
# 7663                NaN  Less than 50 kWh  300 - 399 km
# 6958           فحص كامل               NaN           NaN
# 3382                  3               NaN           NaN

# %%
#storing the number of columns and rows
num_col = df.shape[1] #number of columns
num_rows = df.shape[0] #number of rows
print(f"Number of Attributes",num_col)
print(f"Number of Entries",num_rows)
# Out:
# Number of Attributes 33
# Number of Entries 12003

# %% [markdown]
# The dataset contains *33 Attributes* with *12003 Entries* all of *Object* data type, they could be text, date/time, categorical and numerical; so as a convention they may be converted to the proper data type later in the transformation stage

# %%
#get basic info about dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12003 entries, 0 to 12002
# Data columns (total 33 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   URL                 12003 non-null  object
#  1   Scraped_Time        12003 non-null  object
#  2   Condition           11991 non-null  object
#  3   Car Make            11990 non-null  object
#  4   Model               11990 non-null  object
#  5   Trim                10293 non-null  object
#  6   Year                11992 non-null  object
#  7   Kilometers          11984 non-null  object
#  8   Body Type           11991 non-null  object
#  9   Number of Seats     11986 non-null  object
#  10  Fuel                11984 non-null  object
#  11  Transmission        11984 non-null  object
#  12  Engine Size (cc)    9402 non-null   object
#  13  Exterior Color      11988 non-null  object
#  14  Interior Color      11984 non-null  object
#  15  Regional Specs      11991 non-null  object
#  16  Car License         11984 non-null  object
#  17  Insurance           11984 non-null  object
#  18  Car Customs         11984 non-null  object
#  19  Body Condition      11255 non-null  object
#  20  Paint               11225 non-null  object
#  21  Payment Method      11984 non-null  object
#  22  City                11997 non-null  object
#  23  Neighborhood        11997 non-null  object
#  24  Category            11997 non-null  object
#  25  Subcategory         11997 non-null  object
#  26  Interior Options    11984 non-null  object
#  27  Exterior Options    11984 non-null  object
#  28  Technology Options  11983 non-null  object
#  29  Price               11528 non-null  object
#  30  Description_Score   4767 non-null   object
#  31  Battery Capacity    2100 non-null   object
#  32  Battery Range       2100 non-null   object
# dtypes: object(33)
# memory usage: 3.0+ MB

# %%
#unique values in each attribute
for attr in df.columns:
    print(attr,"\n",df[attr].unique())
# Out:
# URL
#  ['https://jo.opensooq.com/en/search/258270309'
#  'https://jo.opensooq.com/en/search/258415399'
#  'https://jo.opensooq.com/en/search/257669123' ...
#  'https://jo.opensooq.com/en/search/258602761'
#  'https://jo.opensooq.com/en/search/258955829'
#  'https://jo.opensooq.com/en/search/258851377']
# Scraped_Time
#  ['2025-02-06 20:14:39' '2025-02-06 20:16:26' '2025-02-06 20:16:43' ...
#  '2025-02-12 22:17:54' '2025-02-12 22:17:57' '2025-02-12 22:17:58']
# Condition
#  ['Used' 'New' nan]
# Car Make
#  ['Hyundai' 'Tesla' 'Mitsubishi' 'Toyota' 'Kia' 'Lexus' 'Isuzu' 'Ford'
#  'Volkswagen' 'Chevrolet' 'Mercedes Benz' 'Cadillac' 'BMW' 'Land Rover'
#  'Nissan' 'Honda' 'GMC' 'Opel' 'Mazda' 'Samsung' 'Fiat' 'Audi' 'Suzuki'
#  'Leapmotor' 'Peugeot' 'Jeep' 'Lincoln' 'Renault' 'Dodge' 'MG' 'Citroen'
#  'Saab' 'Changan' 'Neta' 'BYD' 'Infiniti' 'Daewoo' 'Skywell' 'Chery'
#  'Daihatsu' 'Genesis' 'Avatar' 'Porsche' 'Dongfeng' 'Jaguar' 'Volvo'
#  'Hongqi' 'Lada' nan 'GAC' 'Abarath' 'Haval' 'Skoda' 'Chrysler' 'Bestune'
#  'Mercury' 'JAC' 'Mahindra' 'Smart' 'Polestar' 'JMEV' 'Great Wall' 'Geely'
#  'Seat' 'Subaru' 'MINI' 'Hunaghai' 'SsangYong' 'Yudo' 'Hummer'
#  'Weltmeister' 'Maserati' 'BAIC' 'Proton' 'Lancia' 'Wuling' 'Pontiac'
#  'Saturn']
# Model
#  ['Accent' 'Avante' 'Model 3' 'L200' 'Ioniq' 'Camry' 'K5' 'ES' 'Highlander'
#  'D-Max' 'Canter' 'Prius' 'Sportage' 'F-150' 'Niro' 'ID 4' 'Malibu'
#  'Fusion' 'E-Class' 'Morning' 'Escalade' 'X5 Series' 'Range Rover Sport'
#  'Galant' 'IS' 'Altima' 'Azera' 'Golf' 'Kicks' 'C-MAX' 'e:N' 'C-Class'
#  'Pajero iO' 'H 100' 'Yukon' 'Omega' 'Sylphy' 'S-Class' '3' 'CT'
#  '5 Series' 'Civic' 'Lancer' 'Sephia' 'SM5' 'Focus' '500' 'Defender' 'Rio'
#  'Sonata' 'Spark' 'HS' 'Corolla' 'R8' 'Caddy' 'S Presso' 'T03' 'CX-9'
#  'EQS-Class' 'Optima' 'Trailblazer' '508' 'Vectra' '208' 'GLE-Class'
#  'Outlander' 'Picanto' 'Camaro' 'Pajero' 'X3 Series' 'Carens' 'H1'
#  'Tiguan' 'Hiace' 'Grand Cherokee' 'MKZ' 'Clio' 'Forte' 'Grand i10' 'Polo'
#  'A6' 'EV6' 'Partner' 'Other' 'Ram' 'EQB-Class' 'Escape' 'Tercel' 'C-HR'
#  'Santa Fe' 'RAV 4' 'Mustang' 'MG ZS EV' 'C2' 'RX' 'Verna' 'Compass'
#  'Accord' 'Navara' '9-5' 'Eado' 'Grand Vitara' 'ID 6' 'Cerato' 'SRX'
#  'Sandero' 'Elantra' 'G-Class' 'Leaf' 'U' 'Tahoe' 'Tucson' 'Land Cruiser'
#  '4 Runner' 'Range Rover' 'bZ' 'Hilux' 'UX' 'Song L' 'Sunny'
#  'Range Rover Velar' 'GX' 'Deepal' 'Song Plus' 'Hunter' 'Tang' 'Q5'
#  'Seagull' 'Wrangler' 'Lavida' 'CS75' 'Insight' 'Envoy' 'Model X' 'Bolt'
#  '207' 'Montero Sport' 'QX80' 'Dokker' 'Niro EV' 'LX' 'CR-V' 'Excel'
#  'X6 Series' 'Nubira' 'Kona' 'Skyworth' 'V-Class' 'Tiggo' '3 Series'
#  'Patrol' 'Sirion' 'Ariya' 'Lotze' 'A8' 'Model Y' 'E-Star' 'Yuan'
#  'Spectra' 'Cruze' 'Captiva' 'NX' 'Charade' 'XLR' 'Explorer' 'CX-5' 'Soul'
#  'Model 12' 'Cielo' 'Q7' '307' 'Range Rover Evoque' 'GLC-Class' 'Sonic'
#  'K3' 'SX4' 'Silverado' 'Sorento' 'Han' 'Terrain' 'Trajet' 'Avalon' 'Bora'
#  'Passat' 'Santamo' 'X-Trail' 'MG 5' 'Cayenne' 'Murano' '7 Series'
#  '4 Series' 'Golf MK' '306' 'Jazz' 'Venza' 'M5' 'A5' 'Tiburon' '206'
#  'M-Class' '308' 'Jetta' 'Expedition' 'Atos' 'XJ' 'Lanos' 'Vitara'
#  'Kadett' 'Aveo' 'Pride' 'ID 3' 'Duster' 'Prado' 'Liberty' 'i10' 'S 80'
#  'Taycan' 'Nammi Box' 'E-HS9' 'Challenger' 'Astra' 'Granta'
#  'Crown Victoria' 'Vesta' nan 'C4' 'iX Series' 'ASX' 'Optra' 'Trooper'
#  'EQA-Class' 'Mirage' 'B-Class' 'CLS-Class' 'e-tron' 'EQE-Class'
#  'EQC-Class' 'Menlo' 'GS' 'Juke' 'Baleno' 'SLC-Class' 'Aion' 'Epica' 'LR4'
#  '595' 'QQ' 'CLA-CLass' 'DTS/De Ville' 'Yaris' 'Box' 'Ranger' 'F-Type'
#  'EX1' 'YRV' 'MG RX8' 'Cobalt' 'Previa' 'Campo' 'Pilot' 'Ecosport' 'Combo'
#  'Shuma' 'Berlingo' 'Carnival' 'CR-Z' 'Besta' 'SM3' 'H6' 'XT4' 'Zoe'
#  'Avanza' 'Roomster' 'MG GT' '407' 'CLE-Class' 'Pregio' 'A4' 'Traverse'
#  'Model S' 'Model 11' 'CTS/Catera' 'CLK-Class' 'e-tron GT' 'Rocky' 'CX-7'
#  'Durango' 'Fabia' '300' 'Qin' 'Staria' 'E2' 'Charger' 'MG HS' 'Micra'
#  'XL7' 'Datsun' 'Alto' 'Zelas' 'Touareg' 'Pointer' 'G37' 'Dolphin'
#  'Cherokee' 'C3' 'Pegas' 'Vita' 'TT' 'Felicia' 'I-Pace' 'SL-Class' '2'
#  '500X' 'Gladiator' 'Mach-E' 'Matrix' 'Sentra' 'Groove' 'Blazer' 'S-Type'
#  'E05' 'XE' 'Q2' 'SL03' 'Q3' 'EV9' 'Mariner' 'Territory' 'LeMans' 'e-JS1'
#  'B70' 'JS3' 'XF' 'Scorpio-N' 'GT' '9-3' 'Fox' 'Reina' 'Korando' 'Fiesta'
#  'Swift' 'Crown' 'ET5' 'Clarity' 'Tiida' 'GLS-Class' 'F3' 'Q50' 'Megane'
#  'Dzire' 'HSE V8' 'Eos' 'FX35' 'X-Type' 'H9' '240' 'Macan' 'SE-Class'
#  'Pathfinder' 'EV3' 'Acadia' 'MG 6' '6 Series' 'Beetle' 'Largus' 'Coupe'
#  'Corvette' 'EQ' 'C 30' 'Sierra' 'Octavia' 'Expert' 'ID 7' 'X-Class'
#  'Stonic' 'A3' 'Geometry C' 'CX-30' 'Xsara' 'Damas' 'CX20' 'Colt' 'Ibiza'
#  'MG RX5' 'Seal' 'Corolla Cross' 'Fortuner' 'Espero' 'i20' '4007'
#  'GLA-Class' 'Atto 3' 'Logan' 'BT-50' 'EV5' 'Panamera' 'Legacy' 'Rogue'
#  'Alsvin' 'Avila' 'Terios' 'Racer' '6' 'N3' 'Doblo' 'Edge' 'Forthing'
#  'Laguna' '107' 'C5' 'FJ' 'E-QM5' 'E06' 'Almera' 'Insignia' 'Veloster'
#  'E10X' 'Corona' 'Celerio' 'Poer' 'RVR' 'Getz' 'Crossfox' 'Frontier' 'Van'
#  'Starlet' 'Impreza' 'Q8 e-tron' 'CL-Class' 'Centennial' 'Azkarra' 'C8'
#  'Avalanche' 'B70S' 'Tacoma' 'Eado XT' 'Lacetti' 'QX50' 'Oprius' 'Jimny'
#  'Cordoba' '2008' 'F-150 Lightning' 'XV' 'ORA' 'H2' 'Kamiq' 'Colorado'
#  'E-2008' 'Trax' 'S 90' 'Maxima' 'Versa' '1500' 'EX5' 'Samara' 'Commander'
#  'i40' 'Figo' 'Suburban' 'QX70' 'Caravan' 'Corsa' 'Niva Legend'
#  'Geometry E' 'CX-3' 'Peri' 'Sienna' 'Wingle' 'City' 'A-Class' 'Q4 e-tron'
#  'Space Wagon' 'Leganza' 'GV80' 'T55' '3000GT' 'CS15' 'Sebring' 'Innova'
#  'XM Series' 'Golf GTI' '740' 'Panda' 'X7 Series' 'F-Pace' 'Quattroporte'
#  'F5' 'Montero' 'Punto' 'Seltos' 'EC7' '406' '106' '911' 'Golf R' 'Neon'
#  'Latitude' 'Huge' 'C11' '5008' '2 Series' 'Bronco' 'T60' 'i-MiEV' 'C'
#  'Creta' 'X Series' 'Santa Cruz' 'MKC' '301' 'i30' 'Cadenza' 'Chana' 'ATS'
#  'HR-V' 'CS95' 'Nitro' 'EV PICKUP' 'Kalos' 'Auris' 'Fluence' 'Mira'
#  'Stepway' 'Boxer' 'LS' 'Palio' 'GV60' 'Mariner Hybrid' 'Honda M-NV' 'BLS'
#  'Lancer Evolution' 'Saga' 'Superb' 'MG ZS' 'Lumina' 'Calibra' 'Tundra'
#  'Lancia' 'BJ Series' 'Ray' 'GR' 'A60' 'XK' 'Symbol' 'GT-Class' 'Quoris'
#  'G80' 'Jumpy' 'ET6' '1' 'Ridgeline' 'QX60' 'T77' 'Pajero Sport' 'Nativa'
#  'Cressida' 'Senova X Series' 'MG One' 'X4 Series' 'D60' 'V3'
#  'Urban Cruiser' 'F0' 'Junior' 'iCar' 'Q30' 'Matiz' 'eQ1' 'Coolbear'
#  'Ciaz' 'T99' 'EU Series' 'Kizashi' 'GLK-Class' 'Q60' 'Okavango'
#  'Teramont' 'SLK-Class' 'Grandeur' 'Mokka' 'H3' 'MKX' 'XC 90']
# Trim
#  ['GL' 'Limited' 'Standard Plus' 'Standard' '5' 'GLE' 'EX' 'ES 300' 'LS'
#  nan 'Eco' 'LX' 'Sport' 'SX Touring' 'ID.4 X' 'Base' 'SEL' 'E 200'
#  'Platinum' 'X5 xDrive40i' 'Autobiography Dynamic' 'DL' 'IS 300' 'S'
#  'Double Cab GLX' 'E-Golf' 'SL' 'e:NS1' 'LXS FWD' 'C 200' 'Denali' 'SV'
#  'GLS' 'S 500' 'CT 200' '525' 'GLX' '1' '2' 'RS' '500e' '110 HSE'
#  'ID.4 Crozz Pure+' '250h Premium' 'ES' 'ID.4 Crozz Pro' 'Titanium' 'GLI'
#  'Coupe' 'Double Cab GL' 'Caddy' 'GTX' 'EQS 450+' 'C 230' '520' 'LT'
#  'GLE 450' 'Prius+' 'GT-Line' '530e' 'XLE' 'X3 xDrive30i' 'Luxury'
#  'GLS Plus' 'Tiguan' 'DX' 'Cargo' 'Laredo' 'Campus' 'Life' 'Sedan'
#  'Wind RWD' 'B9' 'EX Touring' 'Turbo Premium Plus' '1500 Laramie Crew'
#  'EQB 250' 'LE' 'Long Range' 'Hybrid' 'SE' 'GT' 'RX 450h' 'Lariat' 'VTi'
#  'Touring' 'E 350' 'EV460' 'DLX' 'ID.6 Crozz Pro' 'Premium' 'G 500 4x4²'
#  'Autobiography' 'Verso' 'Pro 400' 'LTZ' 'VX' 'Van Long Body' 'HSE'
#  'E 350e' 'bZ3X' '6' 'Prius' 'Golf' 'Vogue HSE' 'UX 300h' 'bZ4X'
#  'R-Dynamic' 'GX 460 Premium' 'S7' 'GXR' 'Rubicon' 'Black Label'
#  'E-lavida' 'Full Option' 'S 350' 'Allex' 'Long Range Plus' 'XLI' 'Wind'
#  'LX 570' 'The X6 M Competition' 'X5 sDrive40i' 'Performance' 'EV6'
#  'Viano' 'E 250' 'Tiggo 5' 'Eado Plus Sport' '320' 'e:NP1' 'LE Titanium'
#  'C 180' 'Empower+ FWD' 'Blue' 'A8 L' 'SEL Premium' 'Prius C' 'NX 300'
#  'V-Series' 'ST' '110' 'ID.6 Crozz Pure+' 'Basic' 'XT' 'Vito' 'Aspire'
#  'GLX Plus' 'Dynamic Plus' 'GLC 350e' 'XL' 'Sportage X-Pro' 'Touring Plus'
#  '1500 Custom' 'SX Prestige AWD' 'XLT' 'X5 xDrive50e' 'E-Bora' 'X-Line'
#  'GT-Line RWD' 'Cayenne S' 'S 450' '740' 'i4 eDrive40' 'Core Plus' 'MK3'
#  'EXi' 'LXi' '528' 'S Carbon Edition' 'C 250' 'Rebel' 'A5 Sportback'
#  'S6 Sedan' '318' 'GL Plus' 'S 400' 'Prime' 'Vogue' 'ML 55 AMG' 'Dynamic'
#  'ID.4 X Pure' 'GLE 350' 'S 320' 'ML 350' '1500 2LT' '1.6T I4 4WD' 'XJ8'
#  '330e' 'ID.3 Pure' 'TXL' 'VXR' 'SQ5 Sportback' 'Premiere' 'Axio' 'G 500'
#  '4S' 'SXT Plus' 'GS' 'CC' 'MK4' '1500 SLT Crew' 'GLC 200' 'C4' 'Sprinter'
#  '316' 'E 300' 'Citan' 'i5 eDrive40' 'G 63 AMG' 'Sahara 4xe' 'CLS 350'
#  'EQE 350' 'EQC 400' 'GS 460' '1500 LT' 'i3 eDrive' 'SLC 350' 'Vogue SE'
#  'LS2' '1LTZ' 'LE HEV' 'Carbon Turbo' 'SX' 'King Ranch'
#  'Limited Edition LR4 Pursuit' 'C 350e' 'XSE' 'CLA 200' 'DTS' 'LX 470'
#  'Other' '530' 'E' 'e:HEV' 'SLE' 'Touring AWD' 'Overland' 'iX3' 'GSe' 'GR'
#  'SL Sport' 'GLC 300' 'Exclusive' 'S Select Sport' 'SX Turbo' 'EX-L'
#  'Techno' 'S 560' 'ID.6 Crozz Pure' 'SW' 'T5' 'C 43 AMG' 'S 280' 'i4 M50'
#  'NX 350h' 'E 240' 'Sportback' 'JX' 'Standard Range' 'S4 Sedan' 'Raptor'
#  'S 300' 'Adenture' 'E 190' 'CLK 200' 'e-tron GT Quattro' 'HSE Dynamic'
#  'Reserve' 'Manual' '300S V6' 'Srt-10' 'ID.6 X Pure' 'R/T'
#  'Van Short Body' 'AT4' 'Plus' 'SR5' 'E Plus HEV' 'C 300' 'CLK 320' 'SE+'
#  'CT 200 F Sport' 'Atmosphere' 'Wind AWD' 'C3' 'GLE-X' 'SQ7' 'TT'
#  'A5 Coupe' 'EcoBoost' 'R-Dynamic S' 'SV Plus' '3500 LT' 'Laredo A' 'GTS'
#  'CLE 450' 'Engage FWD' 'Grand C4 Picasso' 'Tiggo 3' 'SL 43 AMG'
#  'EQE 350 SUV' '735' '500X' 'SR' 'Prestige Plus' 'SL 320' '2LT' 'R-Sport'
#  'ZL1' 'SQ2' 'Standard V6' 'Express' 'Trend' 'Light RWD' 'XE' 'LXS' '730'
#  'Premier' 'Premium Luxury' 'Linear' 'Turbo-x' 'Single Cab GL' 'Dzire'
#  'Combi' 'Crown' 'Active' 'M5' 'i3 eDrive35L' 'CS75 Plus' 'GLS 450' 'JLX'
#  'V 300' 'Core' 'Luxe' 'RX 450' 'Supercharged' 'X-Line EX AWD' 'HST'
#  'Sebastian Vettel Edition' '2.0T Deluxe' 'ID.4 Crozz Prime'
#  'The X5 M Competition' 'GL MID' 'Macan' 'V6 Sport' 'GLS MID' 'SE 300'
#  'SL Plus' 'PHEV' 'Wave' 'RC' 'X6 xDrive40i' '640' 'XL 2500' 'Elegance'
#  'CLA 45 AMG' 'Grand Sport' 'EQ Fortwo Cabriolet' 'Adventure' 'B 250'
#  'ID.7 VIZZION Pro' 'X 250d' 'GX' 'ES 350' 'Willys' 'CLA 220'
#  'GT-Line AWD' 'EQ Forfour' '523' 'Xsara' 'Cross' 'Sahara' 'SV1'
#  'Q5 Sportback' 'Ambition Comfort' 'LX DLX' 'SV Autobiography'
#  'Dynamic HSE' 'Smart' 'Design' 'Turbo' 'GT-Line S' '328' 'GS 350'
#  'GLA 220' 'C 350' 'Ultimate' 'Light Long Range RWD' 'S Premium' 'E2'
#  '1500 ST Regular Cab' 'RX 330' 'Panamera Turbo' 'GTI' 'S Preferred'
#  'S3 Sportback' 'Mid Range' 'EQ Fortwo' 'Cooper' 'Iconic' 'T5 Evo' 'L'
#  'C5 X' 'Cooper S' 'Mach 1' 'Bora' 'X-Line SX AWD' 'Grande' 'GT V6'
#  'GLE 400' 'Turbo R-Spec' 'Aero' '745' 'GLS 500' 'V6' 'GA' '1500 SLE'
#  'Z71' 'High' 'Supercharged Autobiography Ultimate Edition' '1LS' 'LT RS'
#  'GXE' 'RS4 Avant' 'Crew Cab SV' 'X5 M60i' 'XI' '110 X-Dynamic' '1500 1LS'
#  'WRX' 'WRX STI' 'Latitude LUX' '1500 LT Z71' 'AE86' 'CL 320' '1500'
#  'Ultra' 'SX T-GDI' 'E 280' 'ESV Platinum' '1500 RST' 'Cayenne GTS'
#  '2.0 I4 FWD' 'SRT 8' 'Elegance Plus' 'Comfort' 'ES Diamond' 'SE-R V'
#  'Sportage X-Pro Prestige' 'TRD Off-Road' 'SS' 'T6' 'Laredo X' 'EX Plus'
#  'Vector' 'GLC 250' 'L Sport' 'EX-L V6' 'SL03' 'Plaid' 'DLS' 'Pro 500'
#  '110 SE' 'Access A/C' 'S 580' 'ORA EV' 'G' 'SUV' 'Essence' 'SE Sport'
#  'IA' 'Taycan' 'ST-X' '230' '1500 Denali' '1500 LTZ Z71' 'Sport-L'
#  'Limited Sport' 'Style' '3500 SLT' 'EQS 580' 'Grand Touring' 'Klugger'
#  'RS e-tron GT' '250h' 'Z06 C7.R' 'ML 320' 'EQE 350+' 'SL 500' 'Akari'
#  'i3 eDrive40L Yaoye Sports Suit' 'Light Long Range AWD'
#  'Wingle 5 Upgrade' 'LX 600 Ultra Luxury' 'RX 350h'
#  'RS 6 Avant Performance' 'A 200' 'C5 Aircross' 'E HEV' 'EQA 250'
#  'Q4 e-tron' 'LUX' 'LTS' 'SVR' 'Ambiente' 'All Terrain' 'Pure'
#  'Cherokee 4xe' 'SV4' 'Maybach S 580' '1500 PRO' '530i Sedan' 'CLS 550'
#  'LE Platinum' 'SL Sport + OPT' 'E-QM5 BEV' 'i4 eDrive35' 'X7 xDrive40i'
#  'Select' 'i7 xDrive60' 'EQE 500 SUV' 'Autobiography Ultimate Edition'
#  'Carrera' 'EQB 300' 'E3' 'UX 200' 'Golf R' 'Long Range AWD'
#  'EQS 450+ SUV' '300S v8' 'FR' 'LS1' 'Tiggo 2' 'Carbon Edition' 'EXI Plus'
#  'SQ5' 'ESV SR' 'Model S Plaid' '220i' 'Cayenne S E-Hybrid' 'Outer Banks'
#  'GL TOP' 'R-Dynamic SE' 'Elysee' 'Tiggo 2 PRO' 'GR Sport' '750e xDrive'
#  'X35' 'LT Premium' '110 First Edition' 'Daytona R/T' '500c' 'LUXURY'
#  'Longitude' 'S8' 'Hatchback' '1500 SLT Regular Cab' 'Plug-In Hybrid'
#  'Royal' 'CLS 450' 'Vaneo' 'SL 560' 'R/T Mid' 'LX-A' 'EV Edition 1'
#  'Land Cruiser 70' 'Q3 Sportback' 'ID.6 X Pure Long' 'CLA 250'
#  'GLX Medium Line' 'Srt8' 'E 320' 'V 220' 'L4H3' 'Quad CAB' 'SLT' 'LS 460'
#  'ZR2' 'HSE Royal' '325' 'SXT' 'Limited MAX' 'R-Dynamic HSE' 'ES 250' 'IX'
#  '1500 Regular Cab' 'X6 M60i' 'Premium AT' 'GLS Top' 'Overland 4xe'
#  'Lumiere HEV' '740i Sedan' 'ID.4 X Pure Long' 'California Route 1' 'C4 X'
#  '323' '428' 'M3' 'BJ40 PLUS' 'EV' 'Yaris GR' 'Wingle 5 Single Cab' 'Max'
#  'GT Premium' 'Q8 Sportback e-tron' 'E39' 'XKR' 'LS 600' 'GLE 53 AMG'
#  'GT 53' 'Access' 'A 250' 'Black Edition' 'RX' '430i' 'GLS Highline'
#  'Caddy Life' 'Altitude' 'SX+' 'Wildtrak' 'SV2' '330e xDrive' 'Senova X25'
#  'GLX High Line' 'XL SLE' 'X4 xDrive30i' 'Autograph' 'Panamera' 'LX 600'
#  'ES 250 Ultra Luxury' '500 HB' '1500 LT Trail Boss' 'Urban' 'SX Prestige'
#  'XJS' 'Touring SP' 'CC Sport' 'B 200' 'GLE 500' 'SE AWD' 'EU5' 'E1'
#  'GT AWD' 'GLK 250' 'CT 200 Luxury' 'LT2' 'Red Sport 400' '740i xDrive'
#  'V 250' 'LX 600 F Sport Handling' 'iX xDrive50' 'XS' '330' 'GT Line'
#  'GF Premium' 'i3 eDrive40L Night Kit' 'LE Platinum + FES' 'SLK 200'
#  'G 550' 'X5 M50i' 'i4 xDrive40' 'S5 Sportback' 'X Sport' 'Velar' 'Crew'
#  'High Altitude 4xe' 'Panamera 4S' 'Pro' 'T8']
# Year
#  ['2004' '2011' '2022' '2016' '2023' '2009' '2017' '2015' '2010' '2018'
#  '2000' '2021' '1997' '2020' '1999' '2024' '2013' '2019' '2008' '2025'
#  '2001' '2014' '1994' '1998' '2005' '1995' '2006' '2012' '1991' '1989'
#  '1996' '1990' '2007' '2002' '2003' '1992' '1988' '1993' '1987' '1984'
#  '1981' '1970' '1986' '1985' '1983' '1978' '1982' '1973' '1974' '1979'
#  '1971' '1977' '1980' 'Older than 1970' nan]
# Kilometers
#  ['80,000 - 89,999' '130,000 - 139,999' '0' '+200,000' '90,000 - 99,999'
#  '110,000 - 119,999' '120,000 - 129,999' '1 - 999' '10,000 - 19,999'
#  '100,000 - 109,999' '190,000 - 199,999' '150,000 - 159,999'
#  '70,000 - 79,999' '1,000 - 9,999' '50,000 - 59,999' '30,000 - 39,999'
#  '40,000 - 49,999' '20,000 - 29,999' '140,000 - 149,999' '60,000 - 69,999'
#  '180,000 - 189,999' '170,000 - 179,999' '160,000 - 169,999' nan]
# Body Type
#  ['Sedan' 'PickUp' 'SUV' 'Truck' 'HatchBack' 'Coupe' 'Bus - Van'
#  'Convertible' nan]
# Number of Seats
#  ['5' '4' '7' '3' '8' '2' '6' '9' 'More than 9' nan]
# Fuel
#  ['Gasoline' 'Electric' 'Diesel' 'Hybrid' 'Plug-in - Hybrid' 'Mild Hybrid'
#  nan]
# Transmission
#  ['Automatic' 'Manual' nan]
# Engine Size (cc)
#  ['1,000 - 1,999 cc' '500 - 999 cc' nan '2,000 - 2,999 cc'
#  'More than 6,000 cc' '3,000 - 3,999 cc' '5,000 - 5,999 cc' '0 - 499 cc'
#  '4,000 - 4,999 cc']
# Exterior Color
#  ['White' 'Silver' 'Brown' 'Grey' 'Baby Blue' 'Black' 'Bronze' 'Gold'
#  'Blue' 'Nardo Grey' 'Navy Blue' 'Olive Green' 'Red' 'Orange' 'Green'
#  'Yellow' 'Burgundy' 'Petrol' 'Beige' 'Purple' 'Tan' 'Turquoise' 'Pink'
#  nan]
# Interior Color
#  ['Grey' 'Black' 'Nardo Grey' 'Baby Blue' 'Burgundy' 'Beige' 'Silver'
#  'Orange' 'White' 'Bronze' 'Gold' 'Brown' 'Blue' 'Olive Green' 'Navy Blue'
#  'Yellow' 'Tan' 'Red' 'Green' 'Purple' 'Petrol' 'Pink' nan 'Turquoise']
# Regional Specs
#  ['Korean Specs' 'American Specs' 'Japanese Specs' 'Other Specs'
#  'European Specs' 'GCC Specs' nan]
# Car License
#  ['Licensed' 'Not Licensed' nan]
# Insurance
#  ['Compulsory Insurance' 'Comprehensive Insurance' 'Not Insured' nan]
# Car Customs
#  ['With Customs' 'Without Customs' nan]
# Body Condition
#  ['Excellent with no defects' nan 'Other'
#  'Good (body only has minor blemishes)' 'Fair (body needs work)'
#  'Poor (severe body damages)']
# Paint
#  ['Original Paint' nan 'Partially repainted' 'Total repaint' 'Other']
# Payment Method
#  ['Cash or Installments' 'Cash Only' 'Installments Only' nan]
# City
#  ['Irbid' 'Amman' 'Ajloun' 'Mafraq' 'Zarqa' 'Aqaba' 'Madaba' 'Salt'
#  'Al Karak' 'Jerash' 'Ramtha' "Ma'an" 'Tafila' 'Jordan Valley' nan]
# Neighborhood
#  ['Al Quds Street' 'Abu Alanda' 'Tabarboor' 'Marj El Hamam'
#  'Daheit Al Rasheed' 'Al Bayader' 'Shafa Badran' 'Khalda' 'Al Husn'
#  "A'anjara" 'Khirbet Sooq' 'Al-Badiah Ash-Shamaliyah'
#  'Al mantika Al Hurra' 'Sports City' 'Petra Street' 'Al Hay Al Sharqy'
#  'Jabal Al Naser' 'Al Jandaweel' 'Umm Quseir'
#  'Airport Road - Madaba Bridge' 'Sahab'
#  'University of Science and Technology' 'Arhaba' '5th Circle' 'Jubaiha'
#  'Swelieh' 'Abu Nsair' '7th Circle' "Hay Ma'soom" 'Al Thaqafa Circle'
#  'Other' 'Hai Nazzal' "Al-Fayha'" 'Al Sakaneyeh 7' 'Rhab'
#  'Al-Hashmy Street' 'Daheit Al Yasmeen' 'North Shuna' 'Al-Mansour'
#  'Al Hashemieh' 'Jabal Al Ameer Hasan' 'Arjan' 'Dahiet Al-Nakheel'
#  'Airport Road - Manaseer Gs' 'Al Bnayyat' 'Kuforanja' 'Hakama'
#  'Jabal Al Ameer Hamza' 'Thiban' 'Marka' 'Al-Misfat st.' "Al Balqa'"
#  'Dabouq' 'Abdoun' "Tla' Ali" 'Al Muqabalain' 'Al Manarah'
#  'Marka Al Shamaliya' 'Hay AlAmeer Abullah' 'Al-Thra' 'Umm Nowarah'
#  'Mecca Street' "A'llan" 'Al Barha' 'Areinba Al Gharbiyah' 'Mahes'
#  'Al-Hashimiyyah' 'Kufr Asad' 'Madaba Center' 'Al Balad'
#  'Jabal El Shamali  Rusaifeh' 'Al Naseem Circle' 'Wadi Saqra' 'Al-Khaznah'
#  'Dayr Yusuf' 'Al-Imam Al-Ghazali' "Mu'ta" '1st Circle'
#  'Al Hay Al Janooby' 'Downtown' 'Isharet Al Malika Noor'
#  'Al Zarqa Al Jadeedeh' 'Romtha' 'Al Gardens' 'Isharet Al Darawshe'
#  'Shmaisani' 'Al Rabiah' 'Al-Khalidya' 'Umm Al-Rasas' 'Madinet El Sharq'
#  'Birayn' 'Jabal Al Hussain' "Tla' Al Ali Al Shamali" 'Bayt Yafa'
#  'Um El Summaq' 'Al Rahebat Al Wardiah' 'Soof' 'An-Nuayyimah'
#  'Al-Sakaneyeh 8' 'Um Uthaiena Al Gharbi' '8th Circle' 'Yajouz'
#  'Iskan Al Batrawi' 'Jabal Al Nuzha' 'Al-Mazar Al-Janoubi' 'Al Nuzha'
#  'Al Hashmi Al Shamali' 'Huwwarah' 'Daheit Al Aqsa' '6th Circle' 'Abdali'
#  'Awajan' 'Al Autostrad' 'Al Sonbola' 'Hay Al-Zohoor' 'Honaina'
#  'Al-Thuheir' 'University Street' 'Al Saro' 'Daheit Al Ameer Hasan'
#  'Nihla' 'Abu Al-Sous' 'Al-Bustan' 'Al Yadudah' 'Qumaym'
#  'Dahiet Al Ameer Rashed' 'Umm Qais' 'Kofor Youba' 'Al-Abdaliya'
#  'Al-Rabba' 'Deir Ghbar' 'Dhlail' 'Al Qwaismeh' 'Al Sakaneyeh 9'
#  'Ras El Ain' 'Manja' 'Abdoun Al Shamali' 'King Abdullah II Gardens'
#  'Kufr Rakeb' 'Dahiet Al-Istiqlal' 'Ham' 'Marka Al Janoubiya' 'Irbid Mall'
#  'Al-Shabah' 'Al-Qadisyeh - Rusaifeh' 'Jabal Al Zohor'
#  'Dahiet Al Ameer Ali' "Al Mal'ab Al Baladi" 'Al Jizah' 'Al Salalem'
#  'Al Sareeh' 'Airport Road - Dunes Bridge' 'Al Bassah'
#  "Al Madinah Al Sena'eiah" "Al Atiba'" 'Russayfah' 'Wadi El Seer'
#  'Al Torra' 'Hay Al Turokman' '4th Circle' 'Al Lawazem Circle'
#  'Al Hai Al Gharbi' 'Medina Street' 'Al Zawahra' 'Dahiet Al Amera Haya'
#  'Swefieh' 'Al Kursi' 'Hanina' "Ma'an Qasabah" 'Um Uthaiena' 'Al Kamaliya'
#  'Al-Diyar' 'Aydoun' 'Isharet Al Iskan' 'Daheit Makka Al-Mokarameh'
#  'Kharja' 'Jawa' 'Al Dorra Circle' 'Salihiyat Al-Abid' 'Al Sakaneyeh 10'
#  'Samad' 'Iskan Talal - Rusaifeh' "Baqa'a Camp" 'Al-Hay Al-Janoubi'
#  'Al-Mughayer' 'Al Hummar' 'Wadi Musa' 'Naour' 'Al-Mastaba' 'Al-Jweideh'
#  "Al-Mahari'a" 'Al-Badiah Ash-Shamaliyah Al-Gharbiya' 'Al-Qusour' 'Yabla'
#  'Al Tatweer Al Hadari Rusaifah' 'Al-Rabwa' "Dayr as Si'nah" 'Sakib'
#  'Jabal Tareq' 'Sama Al-Rousan' 'Karama' 'Al-Kittah' 'Deir Alla' 'Tibneh'
#  'Al-Thaniyyah' 'Hay Alsaleheen' 'Nayfa' 'Rusaifeh El Janoobi'
#  'Al-Shamiyah' 'Al-Husnyeh' 'Dahiet Al-Rawda' 'Al Qubeh Circle'
#  '3rd Circle' 'Umm Zuwaytinah' 'Hay Al Rahmanieh' 'Iskan Al Dobbat'
#  'Al-Hasa' 'Al Mazar Al-Shamali' 'Hay Al-Rasheed - Rusaifah' 'Safut'
#  'Al-Humranyah' 'Abu Sidu' 'Iskan Al Mohandeseen' 'Bait Ras'
#  'Der Abi Saeed' 'Hay Shaker' 'Kitim' "Wadi Shua'ib" 'Petra'
#  'Jabal Al-Nathif' 'Jabal Al-Lweibdeh' 'Al Ashrafiyah' "Al-Ba'ij"
#  'Jabal Al-Jofah' 'Al ghweariyyeh' 'Mansoura' 'Al Sakaneyeh 3'
#  'Umm Al-Usoud' 'Al-Muwaqqar' 'Hartha' 'Palestine Street'
#  'Albayyada Circle' 'Duwaqarah' 'Ein Al-Basha' 'Jabal Amman' 'Yarga'
#  'Ruwaished' 'Al Manshiyyeh' 'Al Tatweer Al Hadari' 'Daheit Al-Haj Hassan'
#  "E'in Jana" "Kufr Ma'" 'lob' 'Kufr Sowm' 'Shajara' 'Al-Jabal Al-Akhdar'
#  'Badr Jdedeh' 'Hay Al Qaselah' 'Al Rawabi' 'Sal' 'Bushra' "Fo'ara"
#  'Al Hawooz' 'Al Souq' 'Daheit Al Hussain' 'Al-Amir Hamzah'
#  'Al-Faisaliyyah' 'Bayt Idis' 'Bowaydet Al Hawamdeh' 'Al-Ayes' 'Ayl'
#  'Hay Al Ameer Mohammad' 'Abdoun Al Janobi' 'Al Ashrafyeh'
#  'Rujm ash Shami' 'Sahara Circle' 'Al Lubban' 'Al Hurryeh' 'Al-Baida'
#  "I'ra" 'Thaghrat Al-Gub' "Iskan Al Atiba'" 'Aban' 'Al Nasser'
#  'Dayr Al-Kahf' 'Rajm Amesh' 'Al Sakaneyeh 5' 'Salem'
#  'Al Mahdood Al Gharby' 'Dahiet Al Madena Al Monawwara' 'South Shuna'
#  'Al Sukhneh' 'Al Sakaneyeh 6' 'Jabal Al-Taj' 'Al-Hay Al-Hashmi'
#  'Al Eiadat Circle' 'Sammou' 'Hay Albarakeh' 'Al Remeimeen'
#  'Al Urdon Street' 'Al Subeihi' 'Al-Wehdat' 'Al-Shobak' 'Adan'
#  "Tloo' Al-Misdar" 'Al Mazzeh' 'Al-Marqab' 'Eidoon Military Hospital'
#  'Al Qastal' 'Al-Qasr' 'Hay Al Iskan' 'Malka' 'Amrawa'
#  'Al Thawrah Al Arabia Al Kubrah' 'Al-Hamra' 'Natifa' 'Al Shajara'
#  'Kufor Khal' 'Umm Al Amad' 'Um al Basateen' "I'bbeen" 'Juraynah'
#  'Al-Salhiya' 'Hay Al-Dobbat' 'Al-Qatraneh' 'Al-Marj' 'Al-Zafaran'
#  'Al-Fuhais' "Mojamma' Alshaikh Khaleel" 'Azraq' 'Al-Haddadeh' "Mai'n"
#  'Jabal Al Amera Rahma' 'Hay Alia' 'Wadi Al Hajar' 'Wadi Al Aash'
#  '30 Street' 'Um Jozeh' "Al-'Al" 'Harima' 'Al-Yarmouk' 'Qafqafa'
#  "Tla' Al Ali Al Sharqi" 'Um Al Jimal' 'Al Hay Al Gharby' 'Al-Mraigha'
#  "Mojamma' Amman Al Jadeed" 'Zay' "Marsa'" 'As Sarou'
#  'Al Hashmi Al Janobi' 'Al-Naharyah' 'Al-Naseem' 'Al-Raqim' 'Al-Mustanada'
#  'Al Sawarfeh' 'Manshiyyet Bani Hassan' 'Taybeh District' '2nd Circle'
#  'Kuraimah' 'Alkhashafia' 'Al Mahdood Al Wasat' 'Al Herafeyeh'
#  'Dhuheibah Al-Sharqiyah' 'Al-Ghabawi' 'Al Bweida' 'Hanina Al-Gharbiyyah'
#  'Al Rawnaq' 'Hay Al Hussain' 'Jabal Al Abyad' 'Sabha' 'Al-Baqoura'
#  'Al-Mokhaba Al-Tahta' 'Behind Safeway' 'Wadi Al-Rayyan' 'Kafr Hooda'
#  'Kufr Abeel' 'Husban' 'Al Hisbeh Al Markizeya' 'Qweira' 'Bseira'
#  'Al-Mokhayam' 'Al-Mashqar' 'Hay Twaal' "Bala'ama" 'Hay Al Nuzha'
#  'Abu Al-Zighan' 'Um Batima' 'Al-Msherifeh' 'Bweida Al-Ilimat' 'Alal'
#  'Al-Jbeil' 'Sakhra' 'Umm Al-Quttayn' "Sath Ma'an" 'Sama As-Sirhan'
#  'Judayta' 'Sarout' 'Al-Dajaniya' "Al-Za'atari" 'Makhraba' "Alqala'a"
#  'Al-Mugairat' 'Al-Mahatta' 'Bilal' 'Sahm' "A'i" 'Amamah' 'Al-Mabruka'
#  "Um Al Na'am Al Sharqiyyeh" 'Hibras' 'Hay Al Jundi' 'Umm A-Dananir'
#  'Tal Al-Rumman' 'Hayyan Al Moshref' 'Jabal Al-Marrikh' 'Hay Ramzi'
#  'Al Zohour' 'Hofa' 'Jafr' 'Hawshah' 'Marj Al-Furs' 'Sum' 'Tala Bay'
#  'Bahath' 'Idoun' 'Mughayyer Al-Sarhan' 'Hay Al-Hussein' 'Umm Al-Amad'
#  'GhorAl Safi' 'Shomer' 'Zabda' 'Abu Al-Nair' 'Al Mahdood Al Sharqy'
#  'Smma' 'Al-Dhuheibah' 'Dahl' "Faqqu'" 'Al Balad Al Qadeemeh'
#  "Ain wa Al-Ma'mariyyeh" 'Al Rajeeb' 'Hettin Camp' 'Al-Iman' 'Hai Nowarah'
#  'Al Maghareeb' 'Johfiyeh' 'Al Mshairfeh' 'Ghor Al Kafrain'
#  "Mojamma' Al Aghwaar Al Jadeed" 'Areinba Al Sharqiyah' 'Zubiya'
#  'Kufr Awan' 'Al Rama' 'Al Ridwan' 'Al-Oroubah' 'Al-Adnanya' 'Al Khandaq'
#  'Ayla' 'Hay Alkhaledeen' 'Jelul' 'Borma' 'Al-Kharaj'
#  'Qasr al-Hallabat Al-Gharbi' 'Mobes' 'Dead Sea' "Jana'a" "A'fna"
#  'King Abdullah University Hospital' 'Manshiyyet Abu Hammour'
#  'Dalilet Al-Hamaideh' 'Douqara' 'Shafa Al-Amriya' 'Al Midan' "Fa'"
#  'Hatim village' 'Al-Alamiya' 'Al-Qasabat' "Al-Ma'adi"
#  'Al-Dhuheibah Al-Gharbiyah' "Irbid Girl's College" "Fo'ara Street"
#  'Al-Qadisiyyah' 'Al-Saadeh st.' nan 'Um Aldananir' 'Al Jadoor' 'Wadi Rum'
#  'Maru' 'Ghorfat Al Tejara' 'Al-Rawdah' 'Um Uthaiena Al Sharqi' 'Barashta'
#  'Qasr al-Hallabat Al-Sharqi' 'Al-Zamila' 'Zarqa Private University'
#  'Debbin' 'Basman' 'Hawr' 'Badr' 'Zhr' 'Jefen' 'That Ras' 'Um Rummanah'
#  "Al-Khadra'" 'Al-Hussainiyyah' 'Tabaqet Fahel' 'Al-Shaabiyah' 'Graiba'
#  'Sharekat Al Kahraba Circle' 'Waqqas' 'Umm al Kundum' 'Wadi Al Haddadeh'
#  'Ader' 'Inba' "Um Al Na'am Al Gharbiyyeh" 'Al-Mazraa' 'Jajin' 'Jumha'
#  'Madonna']
# Category
#  ['Cars and Bikes' nan]
# Subcategory
#  ['Cars For Sale' nan]
# Interior Options
#  ['Alarm System, AUX / USB Input, Airbags, Electric Windows, Center Lock, CD player, Air Condition'
#  'Airbags, Air Condition, Electric Seat Control, Alarm System, Steering Wheel Controls, Electric Windows, Center Lock, Heated Seats, Leather Seats, AUX / USB Input, Electric rear seat'
#  'Electric Seat Control, Sport Seats, Steering Wheel Controls, Electric rear seat, Memory Seats, Heated Steering Wheel, Electric Windows, Air Condition, Center Lock, Alarm System, Heated Seats, AUX / USB Input, CD player, Airbags, Leather Seats'
#  ... 'Air Condition, Heated Seats, Cooled Seats'
#  'Airbags, Leather Seats, Electric Seat Control, Air Condition, Steering Wheel Controls, Sport Seats, Memory Seats, Electric Windows, Center Lock, Heated Seats, AUX / USB Input, CD player'
#  'Electric Windows, Air Condition, Center Lock, Heated Steering Wheel, Heated Seats, Electric rear seat, AUX / USB Input, CD player, Airbags, Leather Seats, Steering Wheel Controls, Sport Seats, Electric Seat Control, Cooled Seats, Memory Seats, Alarm System']
# Exterior Options
#  ['Daytime Running Lights, Spare Tyre, Rim Wheels, Rear Sensors, Electric Mirrors, Xenon Lights'
#  'Electrically Folding Mirrors, Electric Mirrors, Daytime Running Lights, Xenon Lights, Spare Tyre, Rim Wheels, Rear Sensors, Keyless Entry, Sunroof'
#  'Rear Sensors, Sports Package, Keyless Entry, Back Hook, Sunroof, Panoramic Roof, Electrically Folding Mirrors, Daytime Running Lights, Electric Mirrors, Rim Wheels, Xenon Lights, Front Sensors, LED Lights'
#  ...
#  'Electrically Folding Mirrors, Electric Mirrors, LED Lights, Sports Package, Daytime Running Lights, Back Hook, Rim Wheels, Keyless Entry, Panoramic Roof'
#  'Rear Sensors, Keyless Entry, Electrically Folding Mirrors, Electric Mirrors, LED Lights, Daytime Running Lights, Xenon Lights, Rim Wheels, Front Sensors'
#  'Daytime Running Lights, Rear Sensors, Back Hook, Xenon Lights, Electric Mirrors']
# Technology Options
#  ['Bluetooth, Voice Control, ABS Brakes, Radar'
#  'Touch Screen, Navigation system / maps, Media Screen, ABS Brakes, Apple CarPlay, Auto Lock System, Android Auto, Rear Camera, Bluetooth, Traction Control, Tyre Pressure Monitoring, Cruise Control, Radar, Park assist'
#  'Blind Spot Alert, Auto Lock System, Lane Departure Alert, 360° Camera, Apple CarPlay, Tyre Pressure Monitoring, Rear Camera, Android Auto, Diff Lock, Traction Control, Voice Control, Radar, Cruise Control, Bluetooth, Touch Screen, Park assist, Remote Start, Media Screen, Sport Suspension, Forward Collision Alert, ABS Brakes, Navigation system / maps'
#  ...
#  'Media Screen, Park assist, ABS Brakes, Auto Lock System, Rear Camera, Traction Control, Bluetooth, Cruise Control, Tyre Pressure Monitoring, Sport Suspension, Touch Screen, Navigation system / maps'
#  'Android Auto, Diff Lock, Cruise Control, Voice Control, Radar, Park assist, Bluetooth, Touch Screen, Sport Suspension, Remote Start, Media Screen, Navigation system / maps, Forward Collision Alert, ABS Brakes, Hud Projector, Blind Spot Alert, Auto Lock System, 360° Camera, Lane Departure Alert, Rear Camera, Apple CarPlay, Tyre Pressure Monitoring, Traction Control'
#  'Apple CarPlay, 360° Camera, Bluetooth, Rear Camera, Tyre Pressure Monitoring, Traction Control, Diff Lock, Android Auto, Touch Screen, Media Screen, ABS Brakes, Auto Lock System']
# Price
#  ['4,400 JOD' '8,300 JOD' '21,500 JOD' '15,500 JOD' '21,200 JOD'
#  '7,200 JOD' '14,750 JOD' '20,400 JOD' '10,900 JOD' '12,500 JOD'
#  '8,000 JOD' '13,200 JOD' '18,000 JOD' '15,700 JOD' '16,000 JOD'
#  '15,200 JOD' '22,500 JOD' '5,400 JOD' '6,500 JOD' '10,500 JOD'
#  '14,800 JOD' '2,490 JOD' '34,000 JOD' '7,500 JOD' '55,000 JOD'
#  '3,000 JOD' '42,000 JOD' '18,700 JOD' '5,700 JOD' '23,200 JOD'
#  '22,800 JOD' '15,000 JOD' '10,000 JOD' '8,500 JOD' '789 JOD' '18,900 JOD'
#  '14,000 JOD' '6,000 JOD' '23,500 JOD' '11,250 JOD' '13,000 JOD'
#  '1,000 JOD' '11,900 JOD' '8,800 JOD' '9,999 JOD' '8,350 JOD' '2,100 JOD'
#  '5,500 JOD' '8,900 JOD' '3,500 JOD' '11,800 JOD' '4,600 JOD' '1,550 JOD'
#  '2,000 JOD' '3,200 JOD' '2,900 JOD' '9,500 JOD' '22,000 JOD' '6,200 JOD'
#  '76,000 JOD' '9,000 JOD' '10,700 JOD' '9,300 JOD' '20,800 JOD'
#  '6,900 JOD' '11,000 JOD' '4,000 JOD' '24,800 JOD' '18,500 JOD'
#  '52,000 JOD' '16,500 JOD' '2,200 JOD' '900 JOD' '11,750 JOD' nan
#  '7,900 JOD' '7,000 JOD' '8,200 JOD' '1,650 JOD' '1,950 JOD' '2,800 JOD'
#  '4,200 JOD' '98,000 JOD' '12,600 JOD' '5,000 JOD' '10,300 JOD'
#  '19,000 JOD' '37,500 JOD' '19,500 JOD' '13,900 JOD' '14,200 JOD'
#  '9,650 JOD' '12,000 JOD' '9,850 JOD' '9,600 JOD' '7,300 JOD' '1,900 JOD'
#  '7,800 JOD' '999,999 JOD' '1,700 JOD' '6,800 JOD' '3,700 JOD'
#  '25,000 JOD' '3,400 JOD' '5,300 JOD' '4,500 JOD' '11,950 JOD'
#  '15,900 JOD' '34,200 JOD' '11,400 JOD' '1,850 JOD' '20,000 JOD'
#  '24,500 JOD' '11,500 JOD' '16,250 JOD' '12,900 JOD' '29,500 JOD'
#  '8,850 JOD' '29,000 JOD' '21,000 JOD' '2,999 JOD' '51,000 JOD'
#  '3,800 JOD' '17,700 JOD' '45,000 JOD' '2,400 JOD' '11,850 JOD'
#  '18,300 JOD' '28,000 JOD' '11,350 JOD' '4,900 JOD' '7,400 JOD'
#  '18,799 JOD' '35,000 JOD' '21,900 JOD' '14,500 JOD' '8,700 JOD'
#  '12,800 JOD' '5,200 JOD' '38,000 JOD' '50,000 JOD' '33,500 JOD'
#  '36,500 JOD' '33,000 JOD' '19,400 JOD' '2,700 JOD' '23,000 JOD'
#  '3,250 JOD' '2,500 JOD' '34,900 JOD' '28,700 JOD' '36,000 JOD'
#  '29,900 JOD' '25,500 JOD' '49,000 JOD' '53,000 JOD' '30,000 JOD'
#  '44,000 JOD' '28,500 JOD' '25,900 JOD' '39,700 JOD' '43,500 JOD'
#  '15,250 JOD' '21,600 JOD' '10,850 JOD' '21,700 JOD' '13,499 JOD'
#  '16,750 JOD' '9,800 JOD' '600 JOD' '550 JOD' '39,000 JOD' '13,500 JOD'
#  '1,500 JOD' '20,600 JOD' '39,500 JOD' '5,900 JOD' '14,900 JOD'
#  '31,500 JOD' '3,300 JOD' '999 JOD' '73,000 JOD' '1,350 JOD' '37,000 JOD'
#  '7,250 JOD' '949 JOD' '31,000 JOD' '23,900 JOD' '2,180 JOD' '31,900 JOD'
#  '26,900 JOD' '28,900 JOD' '13,300 JOD' '43,300 JOD' '53,500 JOD'
#  '6,300 JOD' '12,850 JOD' '11,700 JOD' '4,800 JOD' '25,800 JOD'
#  '10,100 JOD' '38,600 JOD' '18,600 JOD' '8,950 JOD' '20,900 JOD'
#  '6,100 JOD' '19,250 JOD' '16,600 JOD' '42,500 JOD' '63,000 JOD'
#  '40,900 JOD' '62,000 JOD' '15,800 JOD' '83,900 JOD' '34,990 JOD'
#  '15,400 JOD' '13,700 JOD' '26,800 JOD' '3,100 JOD' '6,700 JOD'
#  '11,999 JOD' '2,250 JOD' '9,700 JOD' '80,000 JOD' '9,900 JOD'
#  '20,500 JOD' '22,900 JOD' '24,900 JOD' '10,250 JOD' '14,300 JOD'
#  '36,300 JOD' '77,900 JOD' '58,000 JOD' '24,200 JOD' '2,770 JOD'
#  '65,550 JOD' '90,000 JOD' '36,999 JOD' '48,999 JOD' '35,999 JOD'
#  '31,999 JOD' '44,999 JOD' '575 JOD' '173,000 JOD' '4,150 JOD'
#  '11,100 JOD' '35,250 JOD' '25,450 JOD' '177,000 JOD' '16,150 JOD'
#  '77,500 JOD' '16,550 JOD' '29,250 JOD' '2,899 JOD' '109,900 JOD'
#  '32,750 JOD' '22,350 JOD' '4,450 JOD' '22,850 JOD' '3,699 JOD'
#  '13,999 JOD' '138,900 JOD' '80,900 JOD' '35,700 JOD' '13,550 JOD'
#  '7,199 JOD' '16,850 JOD' '25,200 JOD' '5,550 JOD' '22,224 JOD'
#  '63,500 JOD' '28,805 JOD' '2,403 JOD' '29,300 JOD' '75,500 JOD'
#  '33,800 JOD' '207,000 JOD' '18,850 JOD' '10,550 JOD' '14,350 JOD'
#  '20,950 JOD' '81,500 JOD' '43,900 JOD' '30,750 JOD' '39,400 JOD'
#  '135,000 JOD' '82,000 JOD' '70,500 JOD' '66,000 JOD' '35,490 JOD'
#  '21,300 JOD' '37,900 JOD' '89,000 JOD' '49,999 JOD' '27,950 JOD'
#  '37,400 JOD' '47,250 JOD' '26,150 JOD' '31,950 JOD' '13,650 JOD'
#  '8,875 JOD' '33,990 JOD' '30,800 JOD' '42,700 JOD' '23,100 JOD' '799 JOD'
#  '33,400 JOD' '36,950 JOD' '6,875 JOD' '18,350 JOD']
# Description_Score
#  ['فحص كامل' nan '4' '7' '2' '3' '1' '2013' '20062' '20264' '15' '5'
#  '20123' '1500' '20182' '4074' '82' '60' '18002' '6' '867' '28' '1007'
#  '20194' '18004' '20217' '20143' '20002' '400007' '2006' '20232' '20254'
#  '3820007' '3600' '20073' '24']
# Battery Capacity
#  [nan '50 - 69 kWh' '70 - 89 kWh' 'Less than 50 kWh' 'More than 100 kWh'
#  '90 - 99 kWh']
# Battery Range
#  [nan '400 - 499 km' 'More than 500 km' '200 - 299 km' '300 - 399 km'
#  '100 - 199 km' 'Less than 100 km']

# %% [markdown]
# It's important to know that not all missing values are orginated from typical reasons for missing values suach as; user does not enter the data or the bot that did not scrape data probably, where the most of the missing values are orginated from the different types of engines, for example Elctric cars has it's own features that differs from non-elctric cars

# %%
#checking for missing values
df.isnull().sum()
# Out:
# URL                      0
# Scraped_Time             0
# Condition               12
# Car Make                13
# Model                   13
# Trim                  1710
# Year                    11
# Kilometers              19
# Body Type               12
# Number of Seats         17
# Fuel                    19
# Transmission            19
# Engine Size (cc)      2601
# Exterior Color          15
# Interior Color          19
# Regional Specs          12
# Car License             19
# Insurance               19
# Car Customs             19
# Body Condition         748
# Paint                  778
# Payment Method          19
# City                     6
# Neighborhood             6
# Category                 6
# Subcategory              6
# Interior Options        19
# Exterior Options        19
# Technology Options      20
# Price                  475
# Description_Score     7236
# Battery Capacity      9903
# Battery Range         9903
# dtype: int64

# %% [markdown]
# URL' atrribute used as unique identifier, where each link cotains unique id for each car ad, hence URL's are not redundant, and if there is a redundant URL it shuold be removed. As shown in Descovering Structure of the Data section the number of duplicated rows in general are 6, while the number of dulpicates by URL are 76 and that is another reasons why using URL to handle duplicates

# %%
#checking for duplicates for all dataset
df.duplicated().sum()
# Out:
# 6

# %%
#checking for duplicates based on 'URL' atrribute
df['URL'].duplicated().sum()
# Out:
# 76

# %% [markdown]
# ## Data Transformation

# %%
#creating new dataset for cleaning 
clean_df = df.copy()

# %% [markdown]
# ### Handling Irrelevant Atrtibutes

# %% [markdown]
# Attribute with only single value across all data points does not have any significant added value for analysis or modeling, therefore they are dropped

# %%
# printing unique values in 'Category' attribute
clean_df['Category'].unique()
# Out:
# array(['Cars and Bikes', nan], dtype=object)

# %%
# printing unique values in 'Subcategory' attribute
clean_df['Subcategory'].unique()
# Out:
# array(['Cars For Sale', nan], dtype=object)

# %%
clean_df['Description_Score'].unique()
# Out:
# array(['فحص كامل', nan, '4', '7', '2', '3', '1', '2013', '20062', '20264',
#        '15', '5', '20123', '1500', '20182', '4074', '82', '60', '18002',
#        '6', '867', '28', '1007', '20194', '18004', '20217', '20143',
#        '20002', '400007', '2006', '20232', '20254', '3820007', '3600',
#        '20073', '24'], dtype=object)

# %%
#dropping 'Subcategory' and 'Category'
clean_df.drop(columns=['Subcategory','Category','Description_Score'], inplace = True)

# %%
# shape of the data after dropping 'Subcategory' and 'Category'
clean_df.shape
# Out:
# (12003, 30)

# %% [markdown]
# ### Converting Datatpyes

# %% [markdown]
# Converting columns to thair propper datatypes, as following:
# * 'Scraped_Time' from object to date/time.
# * Year from object to integer, where all values under 'Year' attribute are numrical unless one value 'Older than 1970' with count of 5 values, as solving this problem imputation of 'Older than 1970' with '1970' were performed, while the count of the imputed value is very small.
# * converting 'Price' from object to integer; to convert price to integer extracting the price from currency using RegEx then converting it.

# %%
#convert 'Scraped_Time' from object to date/time
clean_df['Scraped_Time'] = pd.to_datetime(clean_df["Scraped_Time"])
clean_df['Scraped_Time'].dtype
# Out:
# dtype('<M8[ns]')

# %%
df[df['Year']== 'Older than 1970'].shape[0]
# Out:
# 5

# %%
clean_df['Year'] = df['Year'].replace('Older than 1970', '1970')

# %%
clean_df[clean_df['Year']== 'Older than 1970'].shape[0]
# Out:
# 0

# %%
#convert 'Year' from object to integer
clean_df["Year"] = clean_df["Year"].astype(float)
clean_df['Year'].dtype
# Out:
# dtype('float64')

# %%
#extracting the price from currency    
clean_df['Price'] = clean_df['Price'].str.replace(r'[^\d.]', '', regex=True)
clean_df['Price'].sample(5)
# Out:
# 6099    34500
# 346     25800
# 4699     5500
# 8985     1200
# 6355     4700
# Name: Price, dtype: object

# %%
#converting 'Price' from object to flaot
clean_df['Price'] = clean_df['Price'].astype(float)
clean_df['Price'].dtype
# Out:
# dtype('float64')

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# ### Handling Missing Value

# %% [markdown]
# Regarding missing values; not all missing values in each attribute are actually misssing, depending on the type of fuel of speceific car, for example Non-Elctric cars don't have 'Battery Capacity' and 'Battery Range', vice versa Elctric cars don't have 'Engine Size (cc)', handling missing values as following:
# * Handling missing values in common attributes between two diffirent types of cars: Non-Elctric and Elctric cars, and handle them by imputation as needed
# * Spliting dataset after cleaning into two main datasets based on cars type
# * Due to the importance of the 'Price' attribute there is a section to handle it's missing values and outliers
# * Records with more than or equal 15 missing values are considered as Corrupted rows, to handle them they were dropped
# *

# %%
#specify selected columns to be handleled either by dropping or imputing 
selected_col = clean_df.select_dtypes(include = ['object']).columns #storing "Object" datatype columns 
selected_col = set(selected_col) #convert from list to set
selected_col = selected_col -  {'Trim','Engine Size (cc)','Body Condition','Paint','Description_Score','Battery Capacity', 'Battery Range','URL','Year'} #select the specefic columns
print(selected_col)
# Out:
# {'Interior Options', 'Regional Specs', 'Fuel', 'Exterior Options', 'Kilometers', 'Body Type', 'Insurance', 'Model', 'Interior Color', 'Transmission', 'Payment Method', 'Technology Options', 'Car License', 'Car Customs', 'City', 'Exterior Color', 'Number of Seats', 'Neighborhood', 'Car Make', 'Condition'}

# %%
# records with 15 or more 
df[df.isna().sum(axis=1)>=15].shape[0]
# Out:
# 19

# %%
#storing indices of corruoted rows that contains more than or equal to 15 missing values
corrupted_rows = clean_df[clean_df.isna().sum(axis=1)>=15].index

# %%
#dropping corrupted rows 
clean_df.drop(corrupted_rows,inplace = True)

# %%
clean_df.shape
# Out:
# (11984, 30)

# %%
clean_df.isna().sum()
# Out:
# URL                      0
# Scraped_Time             0
# Condition                0
# Car Make                 3
# Model                    3
# Trim                  1691
# Year                     0
# Kilometers               0
# Body Type                1
# Number of Seats          2
# Fuel                     0
# Transmission             0
# Engine Size (cc)      2582
# Exterior Color           0
# Interior Color           3
# Regional Specs           0
# Car License              0
# Insurance                0
# Car Customs              0
# Body Condition         730
# Paint                  760
# Payment Method           0
# City                     0
# Neighborhood             0
# Interior Options         0
# Exterior Options         0
# Technology Options       1
# Price                  469
# Battery Capacity      9884
# Battery Range         9884
# dtype: int64

# %%
#filling missing values with most frequency value(mode) in each atrribute
for col in selected_col: #iterating over selected columns 
    print(col,f"-->",clean_df[col].mode()[0]) #printing mode
    clean_df[col] = clean_df[col].fillna(clean_df[col].mode()[0]) #filling missing values
# Out:
# Interior Options --> AUX / USB Input
# Regional Specs --> Korean Specs
# Fuel --> Gasoline
# Exterior Options --> Rim Wheels
# Kilometers --> +200,000
# Body Type --> Sedan
# Insurance --> Compulsory Insurance
# Model --> Avante
# Interior Color --> Black
# Transmission --> Automatic
# Payment Method --> Cash Only
# Technology Options --> Bluetooth
# Car License --> Licensed
# Car Customs --> With Customs
# City --> Amman
# Exterior Color --> White
# Number of Seats --> 5
# Neighborhood --> Al mantika Al Hurra
# Car Make --> Hyundai
# Condition --> Used

# %% [markdown]
# For *'Trim'* atrribute, not all cars have a specific *'Trim'* they just have *'Model'* value; which something depends on the manufacturer of the car, to handle missing values in *'Trim'* atrribute, the value of the *'Model'* of specefic car is imputed in the *'Trim'*; since *'Model'* is the most logical and does not have many missing values

# %%
#finding missing values in 'Trim' and impute them by 'Model' value
clean_df['Trim'] = clean_df['Trim'].fillna(clean_df[clean_df['Trim'].isna()].Model)

# %%
#before imputing 'Model' values in 'Trim'
df[df['URL']=='https://jo.opensooq.com/en/search/257301835']
# Out:
#                                             URL         Scraped_Time  \
# 78  https://jo.opensooq.com/en/search/257301835  2025-02-06 20:19:02
#
#    Condition Car Make   Model Trim  Year       Kilometers Body Type  \
# 78      Used  Hyundai  Sonata  NaN  2018  70,000 - 79,999     Sedan
#
#    Number of Seats    Fuel Transmission  Engine Size (cc) Exterior Color  \
# 78               5  Hybrid    Automatic  1,000 - 1,999 cc          White
#
#    Interior Color Regional Specs Car License             Insurance  \
# 78          Brown   Korean Specs    Licensed  Compulsory Insurance
#
#      Car Customs             Body Condition           Paint Payment Method  \
# 78  With Customs  Excellent with no defects  Original Paint      Cash Only
#
#      City Neighborhood        Category    Subcategory  \
# 78  Amman  Sports City  Cars and Bikes  Cars For Sale
#
#                                      Interior Options  \
# 78  Electric Seat Control, Memory Seats, Steering ...
#
#                                      Exterior Options  \
# 78  Spare Tyre, Rim Wheels, Rear Sensors, Keyless ...
#
#                                    Technology Options       Price  \
# 78  Touch Screen, Voice Control, Media Screen, Bli...  18,500 JOD
#
#    Description_Score Battery Capacity Battery Range
# 78                 7              NaN           NaN

# %%
#after imputing 'Model' values in 'Trim'
clean_df[clean_df['URL']=='https://jo.opensooq.com/en/search/257301835']
# Out:
#                                             URL        Scraped_Time Condition  \
# 78  https://jo.opensooq.com/en/search/257301835 2025-02-06 20:19:02      Used
#
#    Car Make   Model    Trim    Year       Kilometers Body Type  \
# 78  Hyundai  Sonata  Sonata  2018.0  70,000 - 79,999     Sedan
#
#    Number of Seats    Fuel Transmission  Engine Size (cc) Exterior Color  \
# 78               5  Hybrid    Automatic  1,000 - 1,999 cc          White
#
#    Interior Color Regional Specs Car License             Insurance  \
# 78          Brown   Korean Specs    Licensed  Compulsory Insurance
#
#      Car Customs             Body Condition           Paint Payment Method  \
# 78  With Customs  Excellent with no defects  Original Paint      Cash Only
#
#      City Neighborhood                                   Interior Options  \
# 78  Amman  Sports City  Electric Seat Control, Memory Seats, Steering ...
#
#                                      Exterior Options  \
# 78  Spare Tyre, Rim Wheels, Rear Sensors, Keyless ...
#
#                                    Technology Options    Price  \
# 78  Touch Screen, Voice Control, Media Screen, Bli...  18500.0
#
#    Battery Capacity Battery Range
# 78              NaN           NaN

# %% [markdown]
# It was noticed in the 'Body Condition' attribute 655 missing values from 676 have New 'Condition', from the domain view most of the cars of New condition have an Excellent body condition, therefore they were imputed with the value of ''Excellent with no defects', while the rest of missing values of 21 records are imputed with 'Fair (body needs work)'

# %%
# total number of missing values in 'Body Condition'
clean_df['Body Condition'].isna().sum()
# Out:
# 730

# %%
# number of missing values in 'Body Condition' with ['Condition'] == New
clean_df[(clean_df['Body Condition'].isna())&(clean_df['Condition']=='New')].shape[0]
# Out:
# 708

# %%
# impute missing values in 'Body Condition' with condition of ['Condition']=='New' with of 'Excellent with no defects'
clean_df.loc[
    (clean_df['Body Condition'].isna()) & (clean_df['Condition'] == 'New'), 
    'Body Condition'] = clean_df['Body Condition'].fillna('Excellent with no defects')

# %%
# number of the rest of missing values in 'Body Condition'
clean_df['Body Condition'].isna().sum()
# Out:
# 22

# %%
# impute missing values in 'Body Condition' with value of 'Fair (body needs work)'
clean_df.loc[
    (clean_df['Body Condition'].isna()), 
    'Body Condition'] = clean_df['Body Condition'].fillna('Fair (body needs work)')

# %%
clean_df['Body Condition'].isna().sum()
# Out:
# 0

# %% [markdown]
# In 'Paint' attribute showing the origine of the car paint, where 702 are missing 658 are of 'Condition' equal to New, which makes more sense to be 'Original Paint', therefore they were imputed by 'Original Paint', while 44 missing values with 'Condition' equal to Used are imputed with the mode of 'Paint' attribute

# %%
clean_df['Paint'].isna().sum()
# Out:
# 760

# %%
clean_df[(clean_df['Paint'].isna())&(clean_df['Condition']=='New')].shape[0]
# Out:
# 712

# %%
clean_df.loc[
    (clean_df['Paint'].isna()) & (clean_df['Condition'] == 'New'), 
    'Paint'] = clean_df['Paint'].fillna('Original Paint')

# %%
clean_df['Paint'].isna().sum()
# Out:
# 48

# %%
clean_df['Paint'].mode()
# Out:
# 0    Original Paint
# Name: Paint, dtype: object

# %%
clean_df['Paint'].fillna(clean_df['Paint'].mode()[0], inplace=True)

# %%
clean_df['Paint'].isna().sum()
# Out:
# 0

# %%
clean_df[(clean_df['Engine Size (cc)'].isna())&(clean_df['Fuel']!='Electric')].shape[0]
# Out:
# 508

# %%
# Define the condition for missing Engine Size
condition = clean_df['Fuel'].isin(['Gasoline', 'Diesel', 'Hybrid', 'Plug-in - Hybrid', 'Mild Hybrid']) & clean_df['Engine Size (cc)'].isna()

# Step 1: Fill using Model + Year mode
mode_values = clean_df.groupby(["Model", "Year"])['Engine Size (cc)'].transform(lambda x: x.mode().iloc[0] if not x.mode().empty else np.nan)
clean_df.loc[condition, 'Engine Size (cc)'] = mode_values

# Step 2: Fill remaining NaNs using Model-only mode
still_missing = clean_df['Engine Size (cc)'].isna()
mode_values_model = clean_df.groupby("Model")['Engine Size (cc)'].transform(lambda x: x.mode().iloc[0] if not x.mode().empty else np.nan)
clean_df.loc[still_missing, 'Engine Size (cc)'] = mode_values_model

# Step 3: Fill remaining NaNs with the overall mode
overall_mode = clean_df['Engine Size (cc)'].mode()
if not overall_mode.empty:
    clean_df['Engine Size (cc)'].fillna(overall_mode.iloc[0], inplace=True)

# Print remaining NaNs
remaining_missing = clean_df['Engine Size (cc)'].isna().sum()
print(f"Final missing values in 'Engine Size (cc)': {remaining_missing}")
# Out:
# Final missing values in 'Engine Size (cc)': 0

# %%
clean_df[(clean_df['Engine Size (cc)'].isna())&(clean_df['Fuel']!='Electric')].shape[0]
# Out:
# 0

# %% [markdown]
# ### Handling Outliers and Missing Values in 'Price' Attribute

# %% [markdown]
# First handling outliers then handling missing values as following:
# * Grouping cars that have simeller price ranges into groups by 'Model' and 'Year', where the most two significant factors to group cars by are 'Model' and 'Year'
# * After grouping cars, detecting outliers by implementing IQR methode, then dropping outliers
# *  Because of small groups and the most of prices in it are outliers, detecting ouliers by condition, where Year>=2015 and price<=10000 and Payment Methode == 'Cash or Installements' and 'Installements Only', then imputing these outliers by taking the mean of the specefic group
# *  Like the previous step, also imputing outliers but thie time with the following condition: Year>=2010 and price<=3000 and Payment Methode == 'Cash Only'
# *  Still there were 101 record needs handling manually

# %%
backup_df = clean_df.copy()

# %%
def IQR_outliers(gr):
    """
    Identifies outliers in the 'Price' column using the Interquartile Range (IQR) method.

    Parameters:
    -----------
    gr : pandas.DataFrame
        A DataFrame or grouped DataFrame that contains a 'Price' column.

    Returns:
    --------
    pandas.DataFrame
        A subset of the original DataFrame containing only the outlier rows 
        where the 'Price' is below the lower bound or above the upper bound.

    Explanation:
    ------------
    The function follows these steps:
    1. Calculates the first quartile (Q1) and third quartile (Q3) of the 'Price' column.
    2. Computes the Interquartile Range (IQR) as Q3 - Q1.
    3. Defines the lower and upper bounds for detecting outliers:
       - Lower Bound = Q1 - 1.5 * IQR
       - Upper Bound = Q3 + 1.5 * IQR
    4. Filters and returns rows where 'Price' is outside these bounds.
    """

    Q1 = gr['Price'].quantile(0.25)  # First quartile (25th percentile)
    Q3 = gr['Price'].quantile(0.75)  # Third quartile (75th percentile)
    IQR = Q3 - Q1  # Compute the IQR
    lower_bound = Q1 - 1.5 * IQR  # Define lower bound
    upper_bound = Q3 + 1.5 * IQR  # Define upper bound

    # Return only the outlier rows
    return gr[(gr["Price"] < lower_bound) | (gr["Price"] > upper_bound)]

# %% [markdown]
# #### Dropping outliers

# %%
grouped = clean_df.groupby(["Model", "Year"])
grouped.ngroups
# Out:
# 2961

# %%
# detecting outliers in each group
grouped = clean_df.groupby(["Model", "Year"])
dfs = []  # list for adding outliers 
for (model, year), group in grouped: # iterating over groups
    temp =IQR_outliers(group) # detecting outliers
    dfs.append(temp) 
outliers_df = pd.concat(dfs)

# %%
outliers_df.shape[0]
# Out:
# 691

# %%
outliers_indices = outliers_df.index

# %%
# dropping outliers
clean_df.drop(outliers_indices,inplace =True)

# %% [markdown]
# #### Imputing Outliers

# %%
clean_df[((clean_df['Payment Method']=='Cash or Installments')|(clean_df['Payment Method']=='Installments Only'))&(clean_df['Price']<=10000)&(clean_df['Year']>=2015)].shape[0]
# Out:
# 458

# %%
grouped = clean_df.groupby(["Model", "Year"])

for (model, year), group in grouped:
    # Apply condition within each group to avoid reindexing issues
    condition = ((group['Payment Method'].isin(['Cash or Installments', 'Installments Only'])) & 
                 (group['Year'] >= 2015) & 
                 (group['Price'] <= 10000))

    filtered_group = group[condition]  # Apply condition correctly

    if not filtered_group.empty:  # Ensure there are matching rows
        indx = filtered_group.index  # Get indices of matching rows     
        mean_price = group['Price'].mean()  # Mean of the group

        # Update 'Price' for selected rows
        clean_df.loc[indx, 'Price'] = mean_price

print("Final shape of clean_df:", clean_df.shape)
# Out:
# Final shape of clean_df: (11293, 30)

# %%
clean_df[((clean_df['Payment Method']=='Cash or Installments')|(clean_df['Payment Method']=='Installments Only'))&(clean_df['Price']<=3000)&(clean_df['Year']>=2010)].shape[0]
# Out:
# 46

# %%
indx = clean_df[((clean_df['Payment Method']=='Cash or Installments')|(clean_df['Payment Method']=='Installments Only'))&(clean_df['Price']<=3000)&(clean_df['Year']>=2010)].index

# %%
clean_df.drop(indx,inplace =True)

# %%
clean_df.shape
# Out:
# (11247, 30)

# %%
#number of outliers where clean_df['Payment Method']=='Cash Only')&(clean_df['Year']>=2010)
clean_df[(clean_df['Price']<=5000)&(clean_df['Payment Method']=='Cash Only')&(clean_df['Year']>=2010)].shape[0]
# Out:
# 325

# %%
# storing indx of outliers
tmp_indx = clean_df[(clean_df['Price']<=5000)&(clean_df['Payment Method']=='Cash Only')&(clean_df['Year']>=2010)].index
# outliers before imputing
clean_df[(clean_df['Price']<=5000)&(clean_df['Payment Method']=='Cash Only')&(clean_df['Year']>=2010)]
# Out:
#                                                URL        Scraped_Time  \
# 35     https://jo.opensooq.com/en/search/258749739 2025-02-06 20:17:39
# 42     https://jo.opensooq.com/en/search/258749261 2025-02-06 20:17:48
# 74     https://jo.opensooq.com/en/search/258699163 2025-02-06 20:18:55
# 79     https://jo.opensooq.com/en/search/258746185 2025-02-06 20:19:03
# 100    https://jo.opensooq.com/en/search/258745361 2025-02-06 20:19:29
# 162    https://jo.opensooq.com/en/search/257102417 2025-02-06 21:20:32
# 285    https://jo.opensooq.com/en/search/258737337 2025-02-06 21:23:17
# 294    https://jo.opensooq.com/en/search/258512139 2025-02-06 21:23:24
# 315    https://jo.opensooq.com/en/search/258736167 2025-02-06 21:23:45
# 391    https://jo.opensooq.com/en/search/258733895 2025-02-06 21:24:54
# 421    https://jo.opensooq.com/en/search/258732973 2025-02-06 21:25:47
# 434    https://jo.opensooq.com/en/search/258732057 2025-02-06 21:26:18
# 472    https://jo.opensooq.com/en/search/258729985 2025-02-06 21:27:33
# 591    https://jo.opensooq.com/en/search/258672001 2025-02-06 21:32:42
# 609    https://jo.opensooq.com/en/search/258717851 2025-02-06 21:33:03
# 636    https://jo.opensooq.com/en/search/258314841 2025-02-06 21:33:37
# 698    https://jo.opensooq.com/en/search/258112769 2025-02-06 21:35:08
# 769    https://jo.opensooq.com/en/search/258655151 2025-02-06 21:36:30
# 776    https://jo.opensooq.com/en/search/258704483 2025-02-06 21:36:37
# 862    https://jo.opensooq.com/en/search/258696857 2025-02-06 22:26:33
# 863    https://jo.opensooq.com/en/search/257705829 2025-02-06 22:26:34
# 901    https://jo.opensooq.com/en/search/258644639 2025-02-06 22:27:09
# 916    https://jo.opensooq.com/en/search/258693527 2025-02-06 22:27:23
# 931    https://jo.opensooq.com/en/search/257557327 2025-02-06 22:27:39
# 945    https://jo.opensooq.com/en/search/258691923 2025-02-06 22:27:52
# 1060   https://jo.opensooq.com/en/search/258357595 2025-02-06 22:29:50
# 1073   https://jo.opensooq.com/en/search/258683349 2025-02-06 22:30:04
# 1126   https://jo.opensooq.com/en/search/258605725 2025-02-06 22:30:54
# 1151   https://jo.opensooq.com/en/search/258674929 2025-02-06 22:31:17
# 11268  https://jo.opensooq.com/en/search/258288805 2025-02-07 14:13:41
# 11282  https://jo.opensooq.com/en/search/257922271 2025-02-07 14:14:06
# 11338  https://jo.opensooq.com/en/search/257533195 2025-02-07 14:14:52
# 11603  https://jo.opensooq.com/en/search/258896469 2025-02-10 00:05:18
# 11629  https://jo.opensooq.com/en/search/258858633 2025-02-10 00:05:42
# 11701  https://jo.opensooq.com/en/search/258105075 2025-02-10 00:07:53
# 11781  https://jo.opensooq.com/en/search/257135701 2025-02-10 00:09:13
# 11784  https://jo.opensooq.com/en/search/258744953 2025-02-10 00:09:16
# 11792  https://jo.opensooq.com/en/search/257552009 2025-02-10 00:09:24
# 11835  https://jo.opensooq.com/en/search/257965241 2025-02-10 00:10:04
# 11870  https://jo.opensooq.com/en/search/257650919 2025-02-10 00:10:40
# 11924  https://jo.opensooq.com/en/search/258268171 2025-02-12 22:16:51
# 11925  https://jo.opensooq.com/en/search/255053745 2025-02-12 22:16:52
# 11931  https://jo.opensooq.com/en/search/256534123 2025-02-12 22:16:57
# 11932  https://jo.opensooq.com/en/search/258019075 2025-02-12 22:16:58
#
#       Condition       Car Make              Model                  Trim  \
# 35          New          Honda                e:N                 e:NS1
# 42          New           Opel              Omega                 Omega
# 74         Used      Chevrolet              Spark                  Base
# 79         Used         Toyota            Corolla                   GLI
# 100        Used        Peugeot                208              Standard
# 162        Used        Hyundai                 H1              GLS Plus
# 285        Used        Peugeot                207                  Base
# 294        Used          Lexus                 LX                LX 570
# 315        Used          Chery              Tiggo               Tiggo 5
# 391        Used     Mitsubishi          Outlander                   GLX
# 421        Used  Mercedes Benz            E-Class                 E 350
# 434        Used         Nissan               Leaf                     S
# 472        Used            Kia            Sorento       SX Prestige AWD
# 591        Used         Nissan             Murano              Standard
# 609        Used         Nissan              Sunny                     S
# 636        Used        Peugeot                308                 Basic
# 698        Used     Mitsubishi               L200              Standard
# 769        Used           Opel              Astra                    GS
# 776        Used            Kia               Niro            EX Touring
# 862        Used      Chevrolet              Optra              Standard
# 863        Used         Toyota              Hilux                 Hilux
# 901        Used        Hyundai             Accent              Standard
# 916        Used           Jeep           Wrangler            Sahara 4xe
# 931        Used         Toyota       Land Cruiser                   VXR
# 945        Used             MG               MG 5                  MG 5
# 1060       Used        Hyundai             Sonata               Limited
# 1073       Used        Hyundai              Verna              Standard
# 1126       Used          Isuzu              Other                 Other
# 1151       Used          Tesla            Model Y            Long Range
# 1303       Used         Nissan              Sunny                     S
# 1321       Used         Toyota             Avanza                    SE
# 1350       Used      Chevrolet              Spark                    LS
# 1487       Used            BMW          iX Series                   iX3
# 1495       Used        Hyundai             Avante              Standard
# 1533       Used        Peugeot                207                    CC
# 1562       Used        Hyundai             Tucson              Standard
# 1591       Used        Peugeot            Partner        Van Short Body
# 1634       Used             MG              MG HS                 MG HS
# 1667       Used        Peugeot            Partner        Van Short Body
# 1668       Used        Renault             Dokker                Dokker
# 1689       Used         Suzuki               Alto              Standard
# 1696       Used          Isuzu              D-Max                    LS
# 1774       Used        Hyundai                 H1              Standard
# 1803       Used        Citroen                 C4                    C4
# 1841       Used            Kia            Picanto              Standard
# 1855       Used          Chery              Tiggo               Tiggo 3
# 1896       Used  Mercedes Benz            S-Class                 S 320
# 1933       Used         Suzuki               Alto                    GL
# 1940       Used           Audi                 A8                  A8 L
# 2017       Used     Mitsubishi               L200        Double Cab GLX
# 2067       Used        Changan             E-Star                E-Star
# 2120       Used  Mercedes Benz            E-Class                 E 200
# 2128       Used        Peugeot                206              Standard
# 2132       Used         Nissan              Kicks                    SV
# 2165       Used         Nissan              Sunny                     S
# 2187       Used           Ford             Fiesta              Standard
# 2209       Used        Peugeot                207                    GT
# 2241       Used          Tesla            Model X        Standard Range
# 2296        New            BMW           5 Series                    M5
# 2350       Used          Smart              Other                 Other
# 2362       Used            BYD                 F3                    F3
# 2381       Used        Hyundai                 H1              Standard
# 2396       Used     Land Rover  Range Rover Sport          Supercharged
# 2431       Used        Renault               Clio              Standard
# 2436       Used        Citroen                 C3                    C3
# 2464       Used         Nissan               Leaf                    SV
# 2482       Used     Volkswagen                Eos                   Eos
# 2485       Used        Hyundai              Verna              Standard
# 2510       Used        Hyundai                i10                    GL
# 2556       Used            Kia              Forte                    GT
# 2636       Used            Kia            Morning                    LX
# 2659       Used        Renault             Dokker                Dokker
# 2753       Used     Great Wall               C 30                  C 30
# 2762       Used          Skoda            Octavia              Elegance
# 2768       Used            Kia            Morning              Standard
# 2810        New     Volkswagen               ID 7      ID.7 VIZZION Pro
# 2825       Used       Daihatsu             Sirion                Sirion
# 2842       Used            Kia            Spectra               Spectra
# 2863       Used        Peugeot                207                    CC
# 2877       Used        Hyundai              Verna              Standard
# 2958       Used     Mitsubishi          Outlander                   GLS
# 2968       Used      Chevrolet              Spark                  Base
# 3004       Used         Nissan               Leaf                     S
# 3012       Used        Changan               CX20                  CX20
# 3086       Used         Nissan              Micra              Standard
# 3110       Used            Kia                Rio              Standard
# 3174       Used       Daihatsu             Sirion                Sirion
# 3184       Used     Mitsubishi             Lancer              Standard
# 3286       Used       Daihatsu             Sirion                Sirion
# 3299       Used     Land Rover        Range Rover                   HSE
# 3317       Used         Toyota           Fortuner                   SR5
# 3357       Used         Toyota              Yaris                 Basic
# 3389       Used            Kia            Picanto                    EX
# 3391       Used      Chevrolet              Cruze                    LS
# 3401        New     Volkswagen               ID 7      ID.7 VIZZION Pro
# 3415       Used        Hyundai                i20              Standard
# 3418       Used  Mercedes Benz            E-Class                 E 200
# 3473        New  Mercedes Benz            E-Class                 E 200
# 3617       Used      Chevrolet              Cruze                    LT
# 3625       Used         Suzuki               Alto                  Alto
# 3673       Used        Citroen                 C4                    C4
# 3675       Used  Mercedes Benz          EQC-Class               EQC 400
# 3706       Used  Mercedes Benz          EQC-Class               EQC 400
# 3782       Used         Nissan              Sunny                     S
# 3818       Used           Fiat              Doblo                 Doblo
# 3825       Used       Daihatsu             Sirion                Sirion
# 3833       Used            Kia           Sportage        Sportage X-Pro
# 3855       Used        Hyundai             Avante              Standard
# 3982       Used        Hyundai                i10              Standard
# 3986       Used        Hyundai            Elantra              Standard
# 4022        New        Skywell                E06                   E06
# 4072       Used     Mitsubishi             Lancer              Standard
# 4077       Used     Volkswagen             Lavida              E-lavida
# 4115       Used         Suzuki               Alto              Standard
# 4204       Used     Mitsubishi               L200         Double Cab GL
# 4229       Used         Suzuki            Celerio                    GA
# 4296       Used            Kia            Picanto                    LX
# 4338       Used        Hyundai              Ioniq              Standard
# 4417       Used         Toyota              Hilux                   GLX
# 4419       Used     Mitsubishi               L200        Double Cab GLX
# 4430       Used        Peugeot                206              Standard
# 4458       Used        Hyundai             Avante                    SE
# 4467       Used         Nissan              Sunny              Standard
# 4520       Used        Hyundai               Atos                  Atos
# 4602       Used         Nissan              Kicks              Standard
# 4707       Used            Kia              Forte                    GT
# 4716       Used        Hyundai              Verna              Standard
# 4808       Used         Nissan              Sunny                     S
# 4830       Used     Great Wall               C 30                  C 30
# 4863       Used        Hyundai             Avante                    SE
# 4869       Used            Kia            Morning                    EX
# 4905       Used      Chevrolet             Cobalt                    LT
# 4908       Used     Mitsubishi             Lancer                   GLX
# 4910       Used        Hyundai                i10              Standard
# 4929       Used          Smart                 EQ              Standard
# 4977       Used            BMW          X5 Series          X5 xDrive40i
# 5046       Used         Daewoo            Lacetti               Lacetti
# 5074       Used          Tesla            Model S       Long Range Plus
# 5177        New            Kia                EV6           GT-Line RWD
# 5238       Used           Ford              F-150                Lariat
# 5264       Used           Ford    F-150 Lightning                Lariat
# 5293       Used        Renault             Duster              Standard
# 5333       Used        Hyundai                i10              Standard
# 5334       Used         Nissan              Sunny              Standard
# 5344       Used        Renault             Dokker                Dokker
# 5363       Used            Kia            Morning              Standard
# 5454        New            BYD            Seagull               Seagull
# 5473       Used          Lexus                 RX               RX 450h
# 5499       Used         Suzuki               Alto                    GL
# 5516        New  Mercedes Benz          CLE-Class              Standard
# 5534       Used            Kia            Morning                    LX
# 5603       Used        Renault             Dokker                Dokker
# 5635       Used      Chevrolet               Aveo                  Base
# 5658       Used            Kia                 K3                    EX
# 5673       Used          Lexus                 RX               RX 450h
# 5675       Used  Mercedes Benz          EQC-Class               EQC 400
# 5730       Used      Chevrolet              Spark                  Base
# 5761       Used         Nissan              Sunny                     S
# 5793       Used        Porsche             Taycan                Taycan
# 5850       Used        Citroen           Berlingo              Berlingo
# 5884       Used     Great Wall               Peri                  Peri
# 5903       Used     Great Wall             Wingle      Wingle 5 Upgrade
# 5915       Used          Honda            Insight              Standard
# 5941       Used        Renault              Logan                    E2
# 5984       Used      Chevrolet              Cruze                    LS
# 5994       Used      Chevrolet              Spark                    LT
# 6083       Used     Mitsubishi               L200        Double Cab GLX
# 6115       Used          Mazda                  2         Grand Touring
# 6215       Used        Hyundai               Atos                  Atos
# 6237       Used      Chevrolet              Cruze                    LS
# 6252       Used        Peugeot            Partner         Van Long Body
# 6279       Used           Ford              Focus              Standard
# 6285       Used        Porsche             Taycan                    4S
# 6334       Used         Nissan             Patrol           LE Platinum
# 6411       Used     Land Rover  Range Rover Sport     Range Rover Sport
# 6520       Used      Chevrolet               Aveo                    LT
# 6535       Used           Ford    F-150 Lightning              Platinum
# 6563       Used        Hyundai             Avante               Limited
# 6569       Used            Kia            Picanto                    EX
# 6635       Used        Citroen           Berlingo              Berlingo
# 6671       Used        Hyundai             Accent                    GL
# 6693       Used        Peugeot                206              Standard
# 6719       Used        Peugeot                308                    SW
# 6741       Used          Geely                EC7                   EC7
# 6772       Used        Hyundai                i10                    GL
# 6778       Used      Chevrolet              Spark                   LS1
# 6809       Used        Renault           Latitude              Latitude
# 6823       Used         Suzuki               Alto              Standard
# 6831       Used        Peugeot                206              Standard
# 6910       Used        Hyundai             Avante               Limited
# 6930       Used        Hyundai                i10                   GLS
# 7064       Used     Volkswagen              Caddy                 Caddy
# 7140       Used        Porsche            Cayenne    Cayenne S E-Hybrid
# 7148       Used      Chevrolet              Cruze                    LS
# 7150       Used      Chevrolet              Optra              Standard
# 7201       Used         Nissan              Micra              Standard
# 7219       Used           Ford              F-150            King Ranch
# 7264       Used          Chery              Tiggo           Tiggo 2 PRO
# 7314       Used      Chevrolet              Cruze            LT Premium
# 7348       Used        Peugeot                207              Standard
# 7362       Used         Nissan              Sunny                     S
# 7369       Used      Chevrolet              Sonic                  Base
# 7374       Used        Hyundai                 H1                   GLS
# 7518       Used          Geely                EC7                   EC7
# 7525       Used     Mitsubishi             Lancer                    GL
# 7624       Used          Honda            Insight                    EX
# 7697       Used     Land Rover  Range Rover Sport         Autobiography
# 7717       Used            Kia             Sephia                     2
# 7726       Used        Renault              Logan              Standard
# 7763       Used         Nissan               Leaf                    SV
# 7786       Used      Chevrolet               Aveo                    LS
# 7796       Used        Peugeot                207              Standard
# 7824       Used        Peugeot            Partner               Partner
# 7914       Used      Chevrolet              Spark                    LT
# 7945       Used            Kia                EV6  Light Long Range RWD
# 7946       Used            Kia                EV6           GT-Line RWD
# 7948       Used        Hyundai                i20              Standard
# 7979       Used      Chevrolet              Cruze              Standard
# 8034       Used      Chevrolet              Spark                    LS
# 8043       Used  Mercedes Benz            V-Class                 V 220
# 8105        New            GMC            Terrain                   AT4
# 8110       Used            BMW          iX Series                   iX3
# 8185       Used      Chevrolet               Trax                   LTZ
# 8344       Used          Lexus                 LX                LX 570
# 8409       Used        Hyundai             Sonata                  Blue
# 8599       Used         Nissan               Leaf                     S
# 8600       Used         Nissan              Sunny              Standard
# 8631       Used      Chevrolet              Other                 Other
# 8652       Used        Hyundai               Kona                 Sport
# 8725       Used         Nissan              Tiida                 Tiida
# 8749       Used         Nissan              Micra              Standard
# 8757       Used         Nissan              Sunny              Standard
# 8787       Used         Nissan              Sunny               SV Plus
# 8979       Used            Kia               Niro            EX Touring
# 9018       Used        Hyundai               Getz              Standard
# 9040       Used            Kia            Picanto                    LX
# 9045       Used          Mazda                  2              Standard
# 9046       Used     Land Rover  Range Rover Sport     Range Rover Sport
# 9050       Used      Chevrolet              Sonic                    LS
# 9094       Used        Renault            Fluence                    LE
# 9113       Used            Kia            Picanto              Standard
# 9118       Used            Kia                Ray                    EV
# 9140       Used        Peugeot            Partner         Van Long Body
# 9151       Used            Kia             Sephia                     1
# 9199       Used        Peugeot                207              Standard
# 9235       Used           Ford             Escape                    SE
# 9236       Used  Mercedes Benz          CLA-CLass            CLA 45 AMG
# 9315       Used     Land Rover        Range Rover         Autobiography
# 9321       Used         Nissan              Sunny                     S
# 9364       Used        Peugeot            Partner        Van Short Body
# 9374       Used         Suzuki               Alto              Standard
# 9402       Used            Kia                Rio              Standard
# 9448       Used         Nissan               Leaf                     S
# 9451       Used        Hyundai             Avante              Standard
# 9480       Used     Volkswagen              Jetta              Standard
# 9569       Used      Chevrolet               Aveo                    LS
# 9575       Used        Hyundai                 H1              Standard
# 9639       Used            Kia            Sorento       SX Prestige AWD
# 9647        New     Land Rover        Range Rover                   HSE
# 9663        New            BYD            Seagull               Seagull
# 9674       Used            GMC            Terrain                   SLE
# 9680       Used            Kia            Sorento       SX Prestige AWD
# 9682       Used            Kia            Sorento       SX Prestige AWD
# 9710       Used     Land Rover        Range Rover             Vogue HSE
# 9723       Used         Nissan               Leaf              Standard
# 9840       Used        Renault             Dokker                Dokker
# 9841       Used     Land Rover        Range Rover         Autobiography
# 9905       Used            Kia            Picanto              Standard
# 9913       Used        Hyundai            Elantra              Standard
# 9914       Used            Kia               Niro            EX Touring
# 9949       Used         Nissan               Leaf                     S
# 9989       Used           BAIC    Senova X Series            Senova X25
# 10022      Used         Suzuki               Alto              Standard
# 10086      Used         Nissan              Sunny                     S
# 10090      Used         Toyota              Hilux                    SR
# 10098      Used        Hyundai             Avante              Standard
# 10103      Used      Chevrolet              Optra                    LS
# 10126      Used         Toyota              Hilux                   DLX
# 10130      Used     Mitsubishi             Lancer                    GT
# 10179      Used          Honda              Civic                   EXi
# 10205      Used      Chevrolet              Cruze                    LT
# 10218      Used         Toyota              Hilux                   GLX
# 10250      Used         Nissan              Sunny                    SL
# 10315      Used        Peugeot                308                 Basic
# 10392      Used            Kia               Niro            EX Touring
# 10444      Used      Chevrolet          Silverado    1500 LT Trail Boss
# 10453      Used         Suzuki               Alto              Standard
# 10468      Used            BYD                 F0                    F0
# 10501       New     Land Rover        Range Rover         Autobiography
# 10615      Used         Nissan               Juke                    SV
# 10636      Used        Peugeot                207              CC Sport
# 10646      Used      Chevrolet              Optra              Standard
# 10651      Used         Nissan              Ariya            Engage FWD
# 10673      Used         Nissan               Leaf                     S
# 10676      Used     Great Wall           Coolbear              Coolbear
# 10708       New          Isuzu              D-Max                    GT
# 10712      Used        Hyundai              H 100                 H 100
# 10735      Used            Kia            Picanto               Picanto
# 10754      Used         Suzuki               Ciaz                    GL
# 10885      Used           BAIC          EU Series                   EU5
# 10899      Used        Peugeot                301              Standard
# 10918      Used     Land Rover        Range Rover             Vogue HSE
# 10927      Used         Toyota              Hilux                    GL
# 10988      Used            Kia                EV6                GT AWD
# 11016      Used           JMEV              Other                 Other
# 11081      Used         Nissan              Sunny                     S
# 11100      Used     Mitsubishi               L200         Single Cab GL
# 11111      Used        Hyundai            Elantra              Standard
# 11241      Used     Land Rover        Range Rover             Vogue HSE
# 11245       New         Toyota            Corolla                Hybrid
# 11268      Used      Chevrolet             Cobalt                    LT
# 11282      Used     Land Rover        Range Rover                   HSE
# 11338      Used        Hyundai               Atos                  Atos
# 11603      Used            GMC              Yukon                Denali
# 11629      Used     Land Rover        Range Rover                   HSE
# 11701      Used     Land Rover  Range Rover Sport                   HSE
# 11781       New           Neta                  U              Standard
# ...
# 11100  Forward Collision Alert, ABS Brakes, Blind Spo...   999.0
# 11111                                          Bluetooth  3700.0
# 11241  Apple CarPlay, Media Screen, Navigation system...  1000.0
# 11245  Touch Screen, Media Screen, Bluetooth, ABS Bra...  1000.0
# 11268                                   Traction Control  4900.0
# 11282  Tyre Pressure Monitoring, Rear Camera, Diff Lo...  1000.0
# 11338                                   Auto Lock System  3500.0
# 11603  Forward Collision Alert, ABS Brakes, Navigatio...   999.0
# 11629  Remote Start, Media Screen, Sport Suspension, ...  1234.0
# 11701  Hud Projector, Touch Screen, Traction Control,...   999.0
# 11781  Tyre Pressure Monitoring, Navigation system / ...   999.0
# 11784  Tyre Pressure Monitoring, Traction Control, Ra...   999.0
# 11792  Bluetooth, Rear Camera, Forward Collision Aler...  1000.0
# 11835  Voice Control, Traction Control, Bluetooth, Cr...  1234.0
# 11870  Apple CarPlay, Navigation system / maps, Voice...   999.0
# 11924  Apple CarPlay, Touch Screen, Cruise Control, A...   999.0
# 11925  Remote Start, Media Screen, Sport Suspension, ...  3999.0
# 11931  Bluetooth, Remote Start, Forward Collision Ale...  2500.0
# 11932     Bluetooth, Voice Control, Lane Departure Alert  4900.0
#
#         Battery Capacity     Battery Range
# 35           70 - 89 kWh  More than 500 km
# 42                   NaN               NaN
# 74                   NaN               NaN
# 79                   NaN               NaN
# 100                  NaN               NaN
# 162                  NaN               NaN
# 285                  NaN               NaN
# 294                  NaN               NaN
# 315                  NaN               NaN
# 391                  NaN               NaN
# 421                  NaN               NaN
# 434          70 - 89 kWh      100 - 199 km
# 472                  NaN               NaN
# 591                  NaN               NaN
# 609                  NaN               NaN
# 636                  NaN               NaN
# 698                  NaN               NaN
# 769                  NaN               NaN
# 776          70 - 89 kWh  More than 500 km
# 862                  NaN               NaN
# 863                  NaN               NaN
# 901                  NaN               NaN
# 916                  NaN               NaN
# 931                  NaN               NaN
# 945                  NaN               NaN
# 1060                 NaN               NaN
# 1073                 NaN               NaN
# 1126                 NaN               NaN
# 1151   More than 100 kWh  More than 500 km
# 1303                 NaN               NaN
# 1321                 NaN               NaN
# 1350                 NaN               NaN
# 1487         70 - 89 kWh  More than 500 km
# 1495                 NaN               NaN
# 1533                 NaN               NaN
# 1562                 NaN               NaN
# 1591                 NaN               NaN
# 1634                 NaN               NaN
# 1667                 NaN               NaN
# 1668                 NaN               NaN
# 1689                 NaN               NaN
# 1696                 NaN               NaN
# 1774                 NaN               NaN
# 1803                 NaN               NaN
# 1841                 NaN               NaN
# 1855                 NaN               NaN
# 1896                 NaN               NaN
# 1933                 NaN               NaN
# 1940                 NaN               NaN
# 2017                 NaN               NaN
# 2067         50 - 69 kWh      300 - 399 km
# 2120                 NaN               NaN
# 2128                 NaN               NaN
# 2132                 NaN               NaN
# 2165                 NaN               NaN
# 2187                 NaN               NaN
# 2209                 NaN               NaN
# 2241         90 - 99 kWh      400 - 499 km
# 2296                 NaN               NaN
# 2350    Less than 50 kWh      100 - 199 km
# 2362                 NaN               NaN
# 2381                 NaN               NaN
# 2396                 NaN               NaN
# 2431                 NaN               NaN
# 2436                 NaN               NaN
# 2464         50 - 69 kWh  Less than 100 km
# 2482                 NaN               NaN
# 2485                 NaN               NaN
# 2510                 NaN               NaN
# 2556                 NaN               NaN
# 2636                 NaN               NaN
# 2659                 NaN               NaN
# 2753                 NaN               NaN
# 2762                 NaN               NaN
# 2768                 NaN               NaN
# 2810         70 - 89 kWh  More than 500 km
# 2825                 NaN               NaN
# 2842                 NaN               NaN
# 2863                 NaN               NaN
# 2877                 NaN               NaN
# 2958                 NaN               NaN
# 2968                 NaN               NaN
# 3004         70 - 89 kWh  Less than 100 km
# 3012                 NaN               NaN
# 3086                 NaN               NaN
# 3110                 NaN               NaN
# 3174                 NaN               NaN
# 3184                 NaN               NaN
# 3286                 NaN               NaN
# 3299                 NaN               NaN
# 3317                 NaN               NaN
# 3357                 NaN               NaN
# 3389                 NaN               NaN
# 3391                 NaN               NaN
# 3401         70 - 89 kWh  More than 500 km
# 3415                 NaN               NaN
# 3418                 NaN               NaN
# 3473                 NaN               NaN
# 3617                 NaN               NaN
# 3625                 NaN               NaN
# 3673                 NaN               NaN
# 3675         70 - 89 kWh      300 - 399 km
# 3706         70 - 89 kWh      300 - 399 km
# 3782                 NaN               NaN
# 3818                 NaN               NaN
# 3825                 NaN               NaN
# 3833                 NaN               NaN
# 3855                 NaN               NaN
# 3982                 NaN               NaN
# 3986                 NaN               NaN
# 4022         50 - 69 kWh      400 - 499 km
# 4072                 NaN               NaN
# 4077    Less than 50 kWh      200 - 299 km
# 4115                 NaN               NaN
# 4204                 NaN               NaN
# 4229                 NaN               NaN
# 4296                 NaN               NaN
# 4338                 NaN               NaN
# 4417                 NaN               NaN
# 4419                 NaN               NaN
# 4430                 NaN               NaN
# 4458                 NaN               NaN
# 4467                 NaN               NaN
# 4520                 NaN               NaN
# 4602                 NaN               NaN
# 4707                 NaN               NaN
# 4716                 NaN               NaN
# 4808                 NaN               NaN
# 4830                 NaN               NaN
# 4863                 NaN               NaN
# 4869                 NaN               NaN
# 4905                 NaN               NaN
# 4908                 NaN               NaN
# 4910                 NaN               NaN
# 4929   More than 100 kWh  Less than 100 km
# 4977                 NaN               NaN
# 5046                 NaN               NaN
# 5074   More than 100 kWh  More than 500 km
# 5177         70 - 89 kWh  More than 500 km
# 5238   More than 100 kWh  More than 500 km
# 5264   More than 100 kWh  More than 500 km
# 5293                 NaN               NaN
# 5333                 NaN               NaN
# 5334                 NaN               NaN
# 5344                 NaN               NaN
# 5363                 NaN               NaN
# 5454    Less than 50 kWh      400 - 499 km
# 5473                 NaN               NaN
# 5499                 NaN               NaN
# 5516                 NaN               NaN
# 5534                 NaN               NaN
# 5603                 NaN               NaN
# 5635                 NaN               NaN
# 5658                 NaN               NaN
# 5673                 NaN               NaN
# 5675         70 - 89 kWh      400 - 499 km
# 5730                 NaN               NaN
# 5761                 NaN               NaN
# 5793         90 - 99 kWh      400 - 499 km
# 5850                 NaN               NaN
# 5884                 NaN               NaN
# 5903                 NaN               NaN
# 5915                 NaN               NaN
# 5941                 NaN               NaN
# 5984                 NaN               NaN
# 5994                 NaN               NaN
# 6083                 NaN               NaN
# 6115                 NaN               NaN
# 6215                 NaN               NaN
# 6237                 NaN               NaN
# 6252                 NaN               NaN
# 6279                 NaN               NaN
# 6285         90 - 99 kWh  More than 500 km
# 6334                 NaN               NaN
# 6411                 NaN               NaN
# 6520                 NaN               NaN
# 6535   More than 100 kWh  More than 500 km
# 6563                 NaN               NaN
# 6569                 NaN               NaN
# 6635                 NaN               NaN
# 6671                 NaN               NaN
# 6693                 NaN               NaN
# 6719                 NaN               NaN
# 6741                 NaN               NaN
# 6772                 NaN               NaN
# 6778                 NaN               NaN
# 6809                 NaN               NaN
# 6823                 NaN               NaN
# 6831                 NaN               NaN
# 6910                 NaN               NaN
# 6930                 NaN               NaN
# 7064                 NaN               NaN
# 7140                 NaN               NaN
# 7148                 NaN               NaN
# 7150                 NaN               NaN
# 7201                 NaN               NaN
# 7219                 NaN               NaN
# 7264                 NaN               NaN
# 7314                 NaN               NaN
# 7348                 NaN               NaN
# 7362                 NaN               NaN
# 7369                 NaN               NaN
# 7374                 NaN               NaN
# 7518                 NaN               NaN
# 7525                 NaN               NaN
# 7624                 NaN               NaN
# 7697                 NaN               NaN
# 7717                 NaN               NaN
# 7726                 NaN               NaN
# 7763         50 - 69 kWh      100 - 199 km
# 7786                 NaN               NaN
# 7796                 NaN               NaN
# 7824                 NaN               NaN
# 7914                 NaN               NaN
# 7945         70 - 89 kWh  More than 500 km
# 7946         70 - 89 kWh  More than 500 km
# 7948                 NaN               NaN
# 7979                 NaN               NaN
# 8034                 NaN               NaN
# 8043                 NaN               NaN
# 8105                 NaN               NaN
# 8110         70 - 89 kWh      400 - 499 km
# 8185                 NaN               NaN
# 8344                 NaN               NaN
# 8409                 NaN               NaN
# 8599         90 - 99 kWh  Less than 100 km
# 8600                 NaN               NaN
# 8631    Less than 50 kWh  Less than 100 km
# 8652         90 - 99 kWh  More than 500 km
# 8725                 NaN               NaN
# 8749                 NaN               NaN
# 8757                 NaN               NaN
# 8787                 NaN               NaN
# 8979                 NaN               NaN
# 9018                 NaN               NaN
# 9040                 NaN               NaN
# 9045                 NaN               NaN
# 9046                 NaN               NaN
# 9050                 NaN               NaN
# 9094                 NaN               NaN
# 9113                 NaN               NaN
# 9118    Less than 50 kWh  Less than 100 km
# 9140                 NaN               NaN
# 9151                 NaN               NaN
# 9199                 NaN               NaN
# 9235                 NaN               NaN
# 9236                 NaN               NaN
# 9315                 NaN               NaN
# 9321                 NaN               NaN
# 9364                 NaN               NaN
# 9374                 NaN               NaN
# 9402                 NaN               NaN
# 9448    Less than 50 kWh      100 - 199 km
# 9451                 NaN               NaN
# 9480                 NaN               NaN
# 9569                 NaN               NaN
# 9575                 NaN               NaN
# 9639                 NaN               NaN
# 9647                 NaN               NaN
# 9663    Less than 50 kWh      400 - 499 km
# 9674                 NaN               NaN
# 9680                 NaN               NaN
# 9682                 NaN               NaN
# 9710                 NaN               NaN
# 9723    Less than 50 kWh  Less than 100 km
# 9840                 NaN               NaN
# 9841                 NaN               NaN
# 9905                 NaN               NaN
# 9913                 NaN               NaN
# 9914                 NaN               NaN
# 9949    Less than 50 kWh  Less than 100 km
# 9989                 NaN               NaN
# 10022                NaN               NaN
# 10086                NaN               NaN
# 10090                NaN               NaN
# 10098                NaN               NaN
# 10103                NaN               NaN
# 10126                NaN               NaN
# 10130                NaN               NaN
# 10179                NaN               NaN
# 10205                NaN               NaN
# 10218                NaN               NaN
# 10250                NaN               NaN
# 10315                NaN               NaN
# 10392        50 - 69 kWh      400 - 499 km
# 10444                NaN               NaN
# 10453                NaN               NaN
# 10468                NaN               NaN
# 10501                NaN               NaN
# 10615                NaN               NaN
# 10636                NaN               NaN
# 10646                NaN               NaN
# 10651        90 - 99 kWh  More than 500 km
# 10673  More than 100 kWh      100 - 199 km
# 10676                NaN               NaN
# 10708                NaN               NaN
# 10712                NaN               NaN
# 10735                NaN               NaN
# 10754                NaN               NaN
# 10885   Less than 50 kWh      400 - 499 km
# 10899                NaN               NaN
# 10918                NaN               NaN
# 10927                NaN               NaN
# 10988        70 - 89 kWh  More than 500 km
# 11016   Less than 50 kWh      400 - 499 km
# 11081                NaN               NaN
# 11100                NaN               NaN
# 11111                NaN               NaN
# 11241                NaN               NaN
# 11245                NaN               NaN
# 11268                NaN               NaN
# 11282                NaN               NaN
# 11338                NaN               NaN
# 11603                NaN               NaN
# 11629                NaN               NaN
# 11701                NaN               NaN
# 11781        50 - 69 kWh      400 - 499 km
# 11784                NaN               NaN
# 11792                NaN               NaN
# 11835                NaN               NaN
# 11870   Less than 50 kWh      400 - 499 km
# 11924                NaN               NaN
# 11925        70 - 89 kWh  More than 500 km
# 11931                NaN               NaN
# 11932                NaN               NaN

# %%
grouped = clean_df.groupby(["Model", "Year"])

for (model, year), group in grouped:
    # Apply condition within each group to avoid reindexing issues
    condition = ((group['Payment Method'].isin(['Cash Only'])) & 
                 (group['Year'] >= 2010) & 
                 (group['Price'] <= 3000))

    filtered_group = group[condition]  # Apply condition correctly

    if not filtered_group.empty:  # Ensure there are matching rows
        indx = filtered_group.index  # Get indices of matching rows     
        mean_price = group['Price'].mean()  # Mean of the group

        # Update 'Price' for selected rows
        clean_df.loc[indx, 'Price'] = mean_price

print("Final shape of clean_df:", clean_df.shape)
# Out:
# Final shape of clean_df: (11247, 30)

# %%
# after imputing
clean_df.loc[tmp_indx]
# Out:
# 11925  https://jo.opensooq.com/en/search/255053745 2025-02-12 22:16:52
# 11931  https://jo.opensooq.com/en/search/256534123 2025-02-12 22:16:57
# 11932  https://jo.opensooq.com/en/search/258019075 2025-02-12 22:16:58
#
#       Condition       Car Make              Model                  Trim  \
# 35          New          Honda                e:N                 e:NS1
# 42          New           Opel              Omega                 Omega
# 74         Used      Chevrolet              Spark                  Base
# 79         Used         Toyota            Corolla                   GLI
# 100        Used        Peugeot                208              Standard
# 162        Used        Hyundai                 H1              GLS Plus
# 285        Used        Peugeot                207                  Base
# 294        Used          Lexus                 LX                LX 570
# 315        Used          Chery              Tiggo               Tiggo 5
# 391        Used     Mitsubishi          Outlander                   GLX
# 421        Used  Mercedes Benz            E-Class                 E 350
# 434        Used         Nissan               Leaf                     S
# 472        Used            Kia            Sorento       SX Prestige AWD
# 591        Used         Nissan             Murano              Standard
# 609        Used         Nissan              Sunny                     S
# 636        Used        Peugeot                308                 Basic
# 698        Used     Mitsubishi               L200              Standard
# 769        Used           Opel              Astra                    GS
# 776        Used            Kia               Niro            EX Touring
# 862        Used      Chevrolet              Optra              Standard
# 863        Used         Toyota              Hilux                 Hilux
# 901        Used        Hyundai             Accent              Standard
# 916        Used           Jeep           Wrangler            Sahara 4xe
# 931        Used         Toyota       Land Cruiser                   VXR
# 945        Used             MG               MG 5                  MG 5
# 1060       Used        Hyundai             Sonata               Limited
# 1073       Used        Hyundai              Verna              Standard
# 1126       Used          Isuzu              Other                 Other
# 1151       Used          Tesla            Model Y            Long Range
# 1303       Used         Nissan              Sunny                     S
# 1321       Used         Toyota             Avanza                    SE
# 1350       Used      Chevrolet              Spark                    LS
# 1487       Used            BMW          iX Series                   iX3
# 1495       Used        Hyundai             Avante              Standard
# 1533       Used        Peugeot                207                    CC
# 1562       Used        Hyundai             Tucson              Standard
# 1591       Used        Peugeot            Partner        Van Short Body
# 1634       Used             MG              MG HS                 MG HS
# 1667       Used        Peugeot            Partner        Van Short Body
# 1668       Used        Renault             Dokker                Dokker
# 1689       Used         Suzuki               Alto              Standard
# 1696       Used          Isuzu              D-Max                    LS
# 1774       Used        Hyundai                 H1              Standard
# 1803       Used        Citroen                 C4                    C4
# 1841       Used            Kia            Picanto              Standard
# 1855       Used          Chery              Tiggo               Tiggo 3
# 1896       Used  Mercedes Benz            S-Class                 S 320
# 1933       Used         Suzuki               Alto                    GL
# 1940       Used           Audi                 A8                  A8 L
# 2017       Used     Mitsubishi               L200        Double Cab GLX
# 2067       Used        Changan             E-Star                E-Star
# 2120       Used  Mercedes Benz            E-Class                 E 200
# 2128       Used        Peugeot                206              Standard
# 2132       Used         Nissan              Kicks                    SV
# 2165       Used         Nissan              Sunny                     S
# 2187       Used           Ford             Fiesta              Standard
# 2209       Used        Peugeot                207                    GT
# 2241       Used          Tesla            Model X        Standard Range
# 2296        New            BMW           5 Series                    M5
# 2350       Used          Smart              Other                 Other
# 2362       Used            BYD                 F3                    F3
# 2381       Used        Hyundai                 H1              Standard
# 2396       Used     Land Rover  Range Rover Sport          Supercharged
# 2431       Used        Renault               Clio              Standard
# 2436       Used        Citroen                 C3                    C3
# 2464       Used         Nissan               Leaf                    SV
# 2482       Used     Volkswagen                Eos                   Eos
# 2485       Used        Hyundai              Verna              Standard
# 2510       Used        Hyundai                i10                    GL
# 2556       Used            Kia              Forte                    GT
# 2636       Used            Kia            Morning                    LX
# 2659       Used        Renault             Dokker                Dokker
# 2753       Used     Great Wall               C 30                  C 30
# 2762       Used          Skoda            Octavia              Elegance
# 2768       Used            Kia            Morning              Standard
# 2810        New     Volkswagen               ID 7      ID.7 VIZZION Pro
# 2825       Used       Daihatsu             Sirion                Sirion
# 2842       Used            Kia            Spectra               Spectra
# 2863       Used        Peugeot                207                    CC
# 2877       Used        Hyundai              Verna              Standard
# 2958       Used     Mitsubishi          Outlander                   GLS
# 2968       Used      Chevrolet              Spark                  Base
# 3004       Used         Nissan               Leaf                     S
# 3012       Used        Changan               CX20                  CX20
# 3086       Used         Nissan              Micra              Standard
# 3110       Used            Kia                Rio              Standard
# 3174       Used       Daihatsu             Sirion                Sirion
# 3184       Used     Mitsubishi             Lancer              Standard
# 3286       Used       Daihatsu             Sirion                Sirion
# 3299       Used     Land Rover        Range Rover                   HSE
# 3317       Used         Toyota           Fortuner                   SR5
# 3357       Used         Toyota              Yaris                 Basic
# 3389       Used            Kia            Picanto                    EX
# 3391       Used      Chevrolet              Cruze                    LS
# 3401        New     Volkswagen               ID 7      ID.7 VIZZION Pro
# 3415       Used        Hyundai                i20              Standard
# 3418       Used  Mercedes Benz            E-Class                 E 200
# 3473        New  Mercedes Benz            E-Class                 E 200
# 3617       Used      Chevrolet              Cruze                    LT
# 3625       Used         Suzuki               Alto                  Alto
# 3673       Used        Citroen                 C4                    C4
# 3675       Used  Mercedes Benz          EQC-Class               EQC 400
# 3706       Used  Mercedes Benz          EQC-Class               EQC 400
# 3782       Used         Nissan              Sunny                     S
# 3818       Used           Fiat              Doblo                 Doblo
# 3825       Used       Daihatsu             Sirion                Sirion
# 3833       Used            Kia           Sportage        Sportage X-Pro
# 3855       Used        Hyundai             Avante              Standard
# 3982       Used        Hyundai                i10              Standard
# 3986       Used        Hyundai            Elantra              Standard
# 4022        New        Skywell                E06                   E06
# 4072       Used     Mitsubishi             Lancer              Standard
# 4077       Used     Volkswagen             Lavida              E-lavida
# 4115       Used         Suzuki               Alto              Standard
# 4204       Used     Mitsubishi               L200         Double Cab GL
# 4229       Used         Suzuki            Celerio                    GA
# 4296       Used            Kia            Picanto                    LX
# 4338       Used        Hyundai              Ioniq              Standard
# 4417       Used         Toyota              Hilux                   GLX
# 4419       Used     Mitsubishi               L200        Double Cab GLX
# 4430       Used        Peugeot                206              Standard
# 4458       Used        Hyundai             Avante                    SE
# 4467       Used         Nissan              Sunny              Standard
# 4520       Used        Hyundai               Atos                  Atos
# 4602       Used         Nissan              Kicks              Standard
# 4707       Used            Kia              Forte                    GT
# 4716       Used        Hyundai              Verna              Standard
# 4808       Used         Nissan              Sunny                     S
# 4830       Used     Great Wall               C 30                  C 30
# 4863       Used        Hyundai             Avante                    SE
# 4869       Used            Kia            Morning                    EX
# 4905       Used      Chevrolet             Cobalt                    LT
# 4908       Used     Mitsubishi             Lancer                   GLX
# 4910       Used        Hyundai                i10              Standard
# 4929       Used          Smart                 EQ              Standard
# 4977       Used            BMW          X5 Series          X5 xDrive40i
# 5046       Used         Daewoo            Lacetti               Lacetti
# 5074       Used          Tesla            Model S       Long Range Plus
# 5177        New            Kia                EV6           GT-Line RWD
# 5238       Used           Ford              F-150                Lariat
# 5264       Used           Ford    F-150 Lightning                Lariat
# 5293       Used        Renault             Duster              Standard
# 5333       Used        Hyundai                i10              Standard
# 5334       Used         Nissan              Sunny              Standard
# 5344       Used        Renault             Dokker                Dokker
# 5363       Used            Kia            Morning              Standard
# 5454        New            BYD            Seagull               Seagull
# 5473       Used          Lexus                 RX               RX 450h
# 5499       Used         Suzuki               Alto                    GL
# 5516        New  Mercedes Benz          CLE-Class              Standard
# 5534       Used            Kia            Morning                    LX
# 5603       Used        Renault             Dokker                Dokker
# 5635       Used      Chevrolet               Aveo                  Base
# 5658       Used            Kia                 K3                    EX
# 5673       Used          Lexus                 RX               RX 450h
# 5675       Used  Mercedes Benz          EQC-Class               EQC 400
# 5730       Used      Chevrolet              Spark                  Base
# 5761       Used         Nissan              Sunny                     S
# 5793       Used        Porsche             Taycan                Taycan
# 5850       Used        Citroen           Berlingo              Berlingo
# 5884       Used     Great Wall               Peri                  Peri
# 5903       Used     Great Wall             Wingle      Wingle 5 Upgrade
# 5915       Used          Honda            Insight              Standard
# 5941       Used        Renault              Logan                    E2
# 5984       Used      Chevrolet              Cruze                    LS
# 5994       Used      Chevrolet              Spark                    LT
# 6083       Used     Mitsubishi               L200        Double Cab GLX
# 6115       Used          Mazda                  2         Grand Touring
# 6215       Used        Hyundai               Atos                  Atos
# 6237       Used      Chevrolet              Cruze                    LS
# 6252       Used        Peugeot            Partner         Van Long Body
# 6279       Used           Ford              Focus              Standard
# 6285       Used        Porsche             Taycan                    4S
# 6334       Used         Nissan             Patrol           LE Platinum
# 6411       Used     Land Rover  Range Rover Sport     Range Rover Sport
# 6520       Used      Chevrolet               Aveo                    LT
# 6535       Used           Ford    F-150 Lightning              Platinum
# 6563       Used        Hyundai             Avante               Limited
# 6569       Used            Kia            Picanto                    EX
# 6635       Used        Citroen           Berlingo              Berlingo
# 6671       Used        Hyundai             Accent                    GL
# 6693       Used        Peugeot                206              Standard
# 6719       Used        Peugeot                308                    SW
# 6741       Used          Geely                EC7                   EC7
# 6772       Used        Hyundai                i10                    GL
# 6778       Used      Chevrolet              Spark                   LS1
# 6809       Used        Renault           Latitude              Latitude
# 6823       Used         Suzuki               Alto              Standard
# 6831       Used        Peugeot                206              Standard
# 6910       Used        Hyundai             Avante               Limited
# 6930       Used        Hyundai                i10                   GLS
# 7064       Used     Volkswagen              Caddy                 Caddy
# 7140       Used        Porsche            Cayenne    Cayenne S E-Hybrid
# 7148       Used      Chevrolet              Cruze                    LS
# 7150       Used      Chevrolet              Optra              Standard
# 7201       Used         Nissan              Micra              Standard
# 7219       Used           Ford              F-150            King Ranch
# 7264       Used          Chery              Tiggo           Tiggo 2 PRO
# 7314       Used      Chevrolet              Cruze            LT Premium
# 7348       Used        Peugeot                207              Standard
# 7362       Used         Nissan              Sunny                     S
# 7369       Used      Chevrolet              Sonic                  Base
# 7374       Used        Hyundai                 H1                   GLS
# 7518       Used          Geely                EC7                   EC7
# 7525       Used     Mitsubishi             Lancer                    GL
# 7624       Used          Honda            Insight                    EX
# 7697       Used     Land Rover  Range Rover Sport         Autobiography
# 7717       Used            Kia             Sephia                     2
# 7726       Used        Renault              Logan              Standard
# 7763       Used         Nissan               Leaf                    SV
# 7786       Used      Chevrolet               Aveo                    LS
# 7796       Used        Peugeot                207              Standard
# 7824       Used        Peugeot            Partner               Partner
# 7914       Used      Chevrolet              Spark                    LT
# 7945       Used            Kia                EV6  Light Long Range RWD
# 7946       Used            Kia                EV6           GT-Line RWD
# 7948       Used        Hyundai                i20              Standard
# 7979       Used      Chevrolet              Cruze              Standard
# 8034       Used      Chevrolet              Spark                    LS
# 8043       Used  Mercedes Benz            V-Class                 V 220
# 8105        New            GMC            Terrain                   AT4
# 8110       Used            BMW          iX Series                   iX3
# 8185       Used      Chevrolet               Trax                   LTZ
# 8344       Used          Lexus                 LX                LX 570
# 8409       Used        Hyundai             Sonata                  Blue
# 8599       Used         Nissan               Leaf                     S
# 8600       Used         Nissan              Sunny              Standard
# 8631       Used      Chevrolet              Other                 Other
# 8652       Used        Hyundai               Kona                 Sport
# 8725       Used         Nissan              Tiida                 Tiida
# 8749       Used         Nissan              Micra              Standard
# 8757       Used         Nissan              Sunny              Standard
# 8787       Used         Nissan              Sunny               SV Plus
# 8979       Used            Kia               Niro            EX Touring
# 9018       Used        Hyundai               Getz              Standard
# 9040       Used            Kia            Picanto                    LX
# 9045       Used          Mazda                  2              Standard
# 9046       Used     Land Rover  Range Rover Sport     Range Rover Sport
# 9050       Used      Chevrolet              Sonic                    LS
# 9094       Used        Renault            Fluence                    LE
# 9113       Used            Kia            Picanto              Standard
# 9118       Used            Kia                Ray                    EV
# 9140       Used        Peugeot            Partner         Van Long Body
# 9151       Used            Kia             Sephia                     1
# 9199       Used        Peugeot                207              Standard
# 9235       Used           Ford             Escape                    SE
# 9236       Used  Mercedes Benz          CLA-CLass            CLA 45 AMG
# 9315       Used     Land Rover        Range Rover         Autobiography
# 9321       Used         Nissan              Sunny                     S
# 9364       Used        Peugeot            Partner        Van Short Body
# 9374       Used         Suzuki               Alto              Standard
# 9402       Used            Kia                Rio              Standard
# 9448       Used         Nissan               Leaf                     S
# 9451       Used        Hyundai             Avante              Standard
# 9480       Used     Volkswagen              Jetta              Standard
# 9569       Used      Chevrolet               Aveo                    LS
# 9575       Used        Hyundai                 H1              Standard
# 9639       Used            Kia            Sorento       SX Prestige AWD
# 9647        New     Land Rover        Range Rover                   HSE
# 9663        New            BYD            Seagull               Seagull
# 9674       Used            GMC            Terrain                   SLE
# 9680       Used            Kia            Sorento       SX Prestige AWD
# 9682       Used            Kia            Sorento       SX Prestige AWD
# 9710       Used     Land Rover        Range Rover             Vogue HSE
# 9723       Used         Nissan               Leaf              Standard
# 9840       Used        Renault             Dokker                Dokker
# 9841       Used     Land Rover        Range Rover         Autobiography
# 9905       Used            Kia            Picanto              Standard
# 9913       Used        Hyundai            Elantra              Standard
# 9914       Used            Kia               Niro            EX Touring
# 9949       Used         Nissan               Leaf                     S
# 9989       Used           BAIC    Senova X Series            Senova X25
# 10022      Used         Suzuki               Alto              Standard
# 10086      Used         Nissan              Sunny                     S
# 10090      Used         Toyota              Hilux                    SR
# 10098      Used        Hyundai             Avante              Standard
# 10103      Used      Chevrolet              Optra                    LS
# 10126      Used         Toyota              Hilux                   DLX
# 10130      Used     Mitsubishi             Lancer                    GT
# 10179      Used          Honda              Civic                   EXi
# 10205      Used      Chevrolet              Cruze                    LT
# 10218      Used         Toyota              Hilux                   GLX
# 10250      Used         Nissan              Sunny                    SL
# 10315      Used        Peugeot                308                 Basic
# 10392      Used            Kia               Niro            EX Touring
# 10444      Used      Chevrolet          Silverado    1500 LT Trail Boss
# 10453      Used         Suzuki               Alto              Standard
# 10468      Used            BYD                 F0                    F0
# 10501       New     Land Rover        Range Rover         Autobiography
# 10615      Used         Nissan               Juke                    SV
# 10636      Used        Peugeot                207              CC Sport
# 10646      Used      Chevrolet              Optra              Standard
# 10651      Used         Nissan              Ariya            Engage FWD
# 10673      Used         Nissan               Leaf                     S
# 10676      Used     Great Wall           Coolbear              Coolbear
# 10708       New          Isuzu              D-Max                    GT
# 10712      Used        Hyundai              H 100                 H 100
# 10735      Used            Kia            Picanto               Picanto
# 10754      Used         Suzuki               Ciaz                    GL
# 10885      Used           BAIC          EU Series                   EU5
# 10899      Used        Peugeot                301              Standard
# 10918      Used     Land Rover        Range Rover             Vogue HSE
# 10927      Used         Toyota              Hilux                    GL
# 10988      Used            Kia                EV6                GT AWD
# 11016      Used           JMEV              Other                 Other
# 11081      Used         Nissan              Sunny                     S
# 11100      Used     Mitsubishi               L200         Single Cab GL
# 11111      Used        Hyundai            Elantra              Standard
# 11241      Used     Land Rover        Range Rover             Vogue HSE
# 11245       New         Toyota            Corolla                Hybrid
# 11268      Used      Chevrolet             Cobalt                    LT
# 11282      Used     Land Rover        Range Rover                   HSE
# 11338      Used        Hyundai               Atos                  Atos
# 11603      Used            GMC              Yukon                Denali
# 11629      Used     Land Rover        Range Rover                   HSE
# 11701      Used     Land Rover  Range Rover Sport                   HSE
# 11781       New           Neta                  U              Standard
# ...
# 11241  Apple CarPlay, Media Screen, Navigation system...  34149.347500
# 11245  Touch Screen, Media Screen, Bluetooth, ABS Bra...  14651.827160
# 11268                                   Traction Control   4900.000000
# 11282  Tyre Pressure Monitoring, Rear Camera, Diff Lo...  62333.333333
# 11338                                   Auto Lock System   3500.000000
# 11603  Forward Collision Alert, ABS Brakes, Navigatio...  20499.500000
# 11629  Remote Start, Media Screen, Sport Suspension, ...  34149.347500
# 11701  Hud Projector, Touch Screen, Traction Control,...  54515.468750
# 11781  Tyre Pressure Monitoring, Navigation system / ...  15295.826531
# 11784  Tyre Pressure Monitoring, Traction Control, Ra...    999.000000
# 11792  Bluetooth, Rear Camera, Forward Collision Aler...  43175.000000
# 11835  Voice Control, Traction Control, Bluetooth, Cr...  12367.000000
# 11870  Apple CarPlay, Navigation system / maps, Voice...    999.000000
# 11924  Apple CarPlay, Touch Screen, Cruise Control, A...  15499.500000
# 11925  Remote Start, Media Screen, Sport Suspension, ...   3999.000000
# 11931  Bluetooth, Remote Start, Forward Collision Ale...   9872.448980
# 11932     Bluetooth, Voice Control, Lane Departure Alert   4900.000000
#
#         Battery Capacity     Battery Range
# 35           70 - 89 kWh  More than 500 km
# 42                   NaN               NaN
# 74                   NaN               NaN
# 79                   NaN               NaN
# 100                  NaN               NaN
# 162                  NaN               NaN
# 285                  NaN               NaN
# 294                  NaN               NaN
# 315                  NaN               NaN
# 391                  NaN               NaN
# 421                  NaN               NaN
# 434          70 - 89 kWh      100 - 199 km
# 472                  NaN               NaN
# 591                  NaN               NaN
# 609                  NaN               NaN
# 636                  NaN               NaN
# 698                  NaN               NaN
# 769                  NaN               NaN
# 776          70 - 89 kWh  More than 500 km
# 862                  NaN               NaN
# 863                  NaN               NaN
# 901                  NaN               NaN
# 916                  NaN               NaN
# 931                  NaN               NaN
# 945                  NaN               NaN
# 1060                 NaN               NaN
# 1073                 NaN               NaN
# 1126                 NaN               NaN
# 1151   More than 100 kWh  More than 500 km
# 1303                 NaN               NaN
# 1321                 NaN               NaN
# 1350                 NaN               NaN
# 1487         70 - 89 kWh  More than 500 km
# 1495                 NaN               NaN
# 1533                 NaN               NaN
# 1562                 NaN               NaN
# 1591                 NaN               NaN
# 1634                 NaN               NaN
# 1667                 NaN               NaN
# 1668                 NaN               NaN
# 1689                 NaN               NaN
# 1696                 NaN               NaN
# 1774                 NaN               NaN
# 1803                 NaN               NaN
# 1841                 NaN               NaN
# 1855                 NaN               NaN
# 1896                 NaN               NaN
# 1933                 NaN               NaN
# 1940                 NaN               NaN
# 2017                 NaN               NaN
# 2067         50 - 69 kWh      300 - 399 km
# 2120                 NaN               NaN
# 2128                 NaN               NaN
# 2132                 NaN               NaN
# 2165                 NaN               NaN
# 2187                 NaN               NaN
# 2209                 NaN               NaN
# 2241         90 - 99 kWh      400 - 499 km
# 2296                 NaN               NaN
# 2350    Less than 50 kWh      100 - 199 km
# 2362                 NaN               NaN
# 2381                 NaN               NaN
# 2396                 NaN               NaN
# 2431                 NaN               NaN
# 2436                 NaN               NaN
# 2464         50 - 69 kWh  Less than 100 km
# 2482                 NaN               NaN
# 2485                 NaN               NaN
# 2510                 NaN               NaN
# 2556                 NaN               NaN
# 2636                 NaN               NaN
# 2659                 NaN               NaN
# 2753                 NaN               NaN
# 2762                 NaN               NaN
# 2768                 NaN               NaN
# 2810         70 - 89 kWh  More than 500 km
# 2825                 NaN               NaN
# 2842                 NaN               NaN
# 2863                 NaN               NaN
# 2877                 NaN               NaN
# 2958                 NaN               NaN
# 2968                 NaN               NaN
# 3004         70 - 89 kWh  Less than 100 km
# 3012                 NaN               NaN
# 3086                 NaN               NaN
# 3110                 NaN               NaN
# 3174                 NaN               NaN
# 3184                 NaN               NaN
# 3286                 NaN               NaN
# 3299                 NaN               NaN
# 3317                 NaN               NaN
# 3357                 NaN               NaN
# 3389                 NaN               NaN
# 3391                 NaN               NaN
# 3401         70 - 89 kWh  More than 500 km
# 3415                 NaN               NaN
# 3418                 NaN               NaN
# 3473                 NaN               NaN
# 3617                 NaN               NaN
# 3625                 NaN               NaN
# 3673                 NaN               NaN
# 3675         70 - 89 kWh      300 - 399 km
# 3706         70 - 89 kWh      300 - 399 km
# 3782                 NaN               NaN
# 3818                 NaN               NaN
# 3825                 NaN               NaN
# 3833                 NaN               NaN
# 3855                 NaN               NaN
# 3982                 NaN               NaN
# 3986                 NaN               NaN
# 4022         50 - 69 kWh      400 - 499 km
# 4072                 NaN               NaN
# 4077    Less than 50 kWh      200 - 299 km
# 4115                 NaN               NaN
# 4204                 NaN               NaN
# 4229                 NaN               NaN
# 4296                 NaN               NaN
# 4338                 NaN               NaN
# 4417                 NaN               NaN
# 4419                 NaN               NaN
# 4430                 NaN               NaN
# 4458                 NaN               NaN
# 4467                 NaN               NaN
# 4520                 NaN               NaN
# 4602                 NaN               NaN
# 4707                 NaN               NaN
# 4716                 NaN               NaN
# 4808                 NaN               NaN
# 4830                 NaN               NaN
# 4863                 NaN               NaN
# 4869                 NaN               NaN
# 4905                 NaN               NaN
# 4908                 NaN               NaN
# 4910                 NaN               NaN
# 4929   More than 100 kWh  Less than 100 km
# 4977                 NaN               NaN
# 5046                 NaN               NaN
# 5074   More than 100 kWh  More than 500 km
# 5177         70 - 89 kWh  More than 500 km
# 5238   More than 100 kWh  More than 500 km
# 5264   More than 100 kWh  More than 500 km
# 5293                 NaN               NaN
# 5333                 NaN               NaN
# 5334                 NaN               NaN
# 5344                 NaN               NaN
# 5363                 NaN               NaN
# 5454    Less than 50 kWh      400 - 499 km
# 5473                 NaN               NaN
# 5499                 NaN               NaN
# 5516                 NaN               NaN
# 5534                 NaN               NaN
# 5603                 NaN               NaN
# 5635                 NaN               NaN
# 5658                 NaN               NaN
# 5673                 NaN               NaN
# 5675         70 - 89 kWh      400 - 499 km
# 5730                 NaN               NaN
# 5761                 NaN               NaN
# 5793         90 - 99 kWh      400 - 499 km
# 5850                 NaN               NaN
# 5884                 NaN               NaN
# 5903                 NaN               NaN
# 5915                 NaN               NaN
# 5941                 NaN               NaN
# 5984                 NaN               NaN
# 5994                 NaN               NaN
# 6083                 NaN               NaN
# 6115                 NaN               NaN
# 6215                 NaN               NaN
# 6237                 NaN               NaN
# 6252                 NaN               NaN
# 6279                 NaN               NaN
# 6285         90 - 99 kWh  More than 500 km
# 6334                 NaN               NaN
# 6411                 NaN               NaN
# 6520                 NaN               NaN
# 6535   More than 100 kWh  More than 500 km
# 6563                 NaN               NaN
# 6569                 NaN               NaN
# 6635                 NaN               NaN
# 6671                 NaN               NaN
# 6693                 NaN               NaN
# 6719                 NaN               NaN
# 6741                 NaN               NaN
# 6772                 NaN               NaN
# 6778                 NaN               NaN
# 6809                 NaN               NaN
# 6823                 NaN               NaN
# 6831                 NaN               NaN
# 6910                 NaN               NaN
# 6930                 NaN               NaN
# 7064                 NaN               NaN
# 7140                 NaN               NaN
# 7148                 NaN               NaN
# 7150                 NaN               NaN
# 7201                 NaN               NaN
# 7219                 NaN               NaN
# 7264                 NaN               NaN
# 7314                 NaN               NaN
# 7348                 NaN               NaN
# 7362                 NaN               NaN
# 7369                 NaN               NaN
# 7374                 NaN               NaN
# 7518                 NaN               NaN
# 7525                 NaN               NaN
# 7624                 NaN               NaN
# 7697                 NaN               NaN
# 7717                 NaN               NaN
# 7726                 NaN               NaN
# 7763         50 - 69 kWh      100 - 199 km
# 7786                 NaN               NaN
# 7796                 NaN               NaN
# 7824                 NaN               NaN
# 7914                 NaN               NaN
# 7945         70 - 89 kWh  More than 500 km
# 7946         70 - 89 kWh  More than 500 km
# 7948                 NaN               NaN
# 7979                 NaN               NaN
# 8034                 NaN               NaN
# 8043                 NaN               NaN
# 8105                 NaN               NaN
# 8110         70 - 89 kWh      400 - 499 km
# 8185                 NaN               NaN
# 8344                 NaN               NaN
# 8409                 NaN               NaN
# 8599         90 - 99 kWh  Less than 100 km
# 8600                 NaN               NaN
# 8631    Less than 50 kWh  Less than 100 km
# 8652         90 - 99 kWh  More than 500 km
# 8725                 NaN               NaN
# 8749                 NaN               NaN
# 8757                 NaN               NaN
# 8787                 NaN               NaN
# 8979                 NaN               NaN
# 9018                 NaN               NaN
# 9040                 NaN               NaN
# 9045                 NaN               NaN
# 9046                 NaN               NaN
# 9050                 NaN               NaN
# 9094                 NaN               NaN
# 9113                 NaN               NaN
# 9118    Less than 50 kWh  Less than 100 km
# 9140                 NaN               NaN
# 9151                 NaN               NaN
# 9199                 NaN               NaN
# 9235                 NaN               NaN
# 9236                 NaN               NaN
# 9315                 NaN               NaN
# 9321                 NaN               NaN
# 9364                 NaN               NaN
# 9374                 NaN               NaN
# 9402                 NaN               NaN
# 9448    Less than 50 kWh      100 - 199 km
# 9451                 NaN               NaN
# 9480                 NaN               NaN
# 9569                 NaN               NaN
# 9575                 NaN               NaN
# 9639                 NaN               NaN
# 9647                 NaN               NaN
# 9663    Less than 50 kWh      400 - 499 km
# 9674                 NaN               NaN
# 9680                 NaN               NaN
# 9682                 NaN               NaN
# 9710                 NaN               NaN
# 9723    Less than 50 kWh  Less than 100 km
# 9840                 NaN               NaN
# 9841                 NaN               NaN
# 9905                 NaN               NaN
# 9913                 NaN               NaN
# 9914                 NaN               NaN
# 9949    Less than 50 kWh  Less than 100 km
# 9989                 NaN               NaN
# 10022                NaN               NaN
# 10086                NaN               NaN
# 10090                NaN               NaN
# 10098                NaN               NaN
# 10103                NaN               NaN
# 10126                NaN               NaN
# 10130                NaN               NaN
# 10179                NaN               NaN
# 10205                NaN               NaN
# 10218                NaN               NaN
# 10250                NaN               NaN
# 10315                NaN               NaN
# 10392        50 - 69 kWh      400 - 499 km
# 10444                NaN               NaN
# 10453                NaN               NaN
# 10468                NaN               NaN
# 10501                NaN               NaN
# 10615                NaN               NaN
# 10636                NaN               NaN
# 10646                NaN               NaN
# 10651        90 - 99 kWh  More than 500 km
# 10673  More than 100 kWh      100 - 199 km
# 10676                NaN               NaN
# 10708                NaN               NaN
# 10712                NaN               NaN
# 10735                NaN               NaN
# 10754                NaN               NaN
# 10885   Less than 50 kWh      400 - 499 km
# 10899                NaN               NaN
# 10918                NaN               NaN
# 10927                NaN               NaN
# 10988        70 - 89 kWh  More than 500 km
# 11016   Less than 50 kWh      400 - 499 km
# 11081                NaN               NaN
# 11100                NaN               NaN
# 11111                NaN               NaN
# 11241                NaN               NaN
# 11245                NaN               NaN
# 11268                NaN               NaN
# 11282                NaN               NaN
# 11338                NaN               NaN
# 11603                NaN               NaN
# 11629                NaN               NaN
# 11701                NaN               NaN
# 11781        50 - 69 kWh      400 - 499 km
# 11784                NaN               NaN
# 11792                NaN               NaN
# 11835                NaN               NaN
# 11870   Less than 50 kWh      400 - 499 km
# 11924                NaN               NaN
# 11925        70 - 89 kWh  More than 500 km
# 11931                NaN               NaN
# 11932                NaN               NaN

# %% [markdown]
# #### Handling Missing Values in 'Price' Attribute

# %%
grouped = clean_df.groupby(["Model", "Year"])
for (model, year), group in grouped:
    if group['Price'].isna().any():
        indx = group['Price'][group['Price'].isna()].index  # Only missing values

        if group.shape[0] <= 2:
            car_make_value = group['Car Make'].iloc[0]
            mean_price = clean_df[clean_df['Car Make'] == car_make_value]['Price'].mean()

            # Update ONLY NaN values without affecting other columns
            clean_df.loc[indx, 'Price'] = clean_df.loc[indx, 'Price'].fillna(mean_price)

        elif group.shape[0] > 2:
            clean_df.loc[indx, 'Price'] = clean_df.loc[indx, 'Price'].fillna(group['Price'].mean())

print("Final shape of clean_df:", clean_df.shape)
# Out:
# Final shape of clean_df: (11247, 30)

# %%
clean_df[clean_df['Price'].isna()].shape[0]
# Out:
# 11

# %%
indx2 = clean_df[clean_df['Price'].isna()].index

# %%
clean_df.drop(indx2,inplace =True)

# %%
clean_df.shape
# Out:
# (11236, 30)

# %%
# unhandeled outliers
clean_df[clean_df['Price']<=1001].shape[0]
# Out:
# 106

# %%
# stronig indx of unhandeled outliers
groupless_outliers = clean_df[clean_df['Price']<=1001].index

# %%
# final count of missing values
clean_df.isna().sum()
# Out:
# URL                      0
# Scraped_Time             0
# Condition                0
# Car Make                 0
# Model                    0
# Trim                     0
# Year                     0
# Kilometers               0
# Body Type                0
# Number of Seats          0
# Fuel                     0
# Transmission             0
# Engine Size (cc)         0
# Exterior Color           0
# Interior Color           0
# Regional Specs           0
# Car License              0
# Insurance                0
# Car Customs              0
# Body Condition           0
# Paint                    0
# Payment Method           0
# City                     0
# Neighborhood             0
# Interior Options         0
# Exterior Options         0
# Technology Options       0
# Price                    0
# Battery Capacity      9322
# Battery Range         9322
# dtype: int64

# %%
# final shape of the dataset
clean_df.shape
# Out:
# (11236, 30)

# %%
#converting 'Price' from object to flaot
clean_df['Price'] = clean_df['Price'].astype(int)
clean_df['Price'].dtype
# Out:
# dtype('int32')

# %%
#convert 'Year' from object to integer
clean_df["Year"] = clean_df["Year"].astype(int)
clean_df['Year'].dtype
# Out:
# dtype('int32')

# %% [markdown]
# ### Handling Duplicated Entities

# %% [markdown]
# *'URL'* atrribute used as unique identifier, where each link cotains unique *id* for each car ad, hence *URL's* are not redundant, and if there is a redundant *URL* it shuold be removed.
# As shown in *Descovering Structure of the Data* section the number of duplicated rows in general are 6, while the number of dulpicates by *URL* are 76 and that is another reasons why using *URL* to handle duplicates

# %%
clean_df.duplicated(subset = ['URL']).sum()
# Out:
# 67

# %%
clean_df.drop_duplicates(subset = ['URL'], inplace = True)

# %%
clean_df.shape
# Out:
# (11169, 30)

# %% [markdown]
# ## Spliting & Exporting Data

# %%
electric_cars_df = clean_df[clean_df['Fuel'] == 'Electric'].copy()
electric_cars_df.drop(columns = ['Engine Size (cc)'], inplace = True)
electric_cars_df.shape
# Out:
# (1876, 29)

# %%
non_electric_cars_df = clean_df[(clean_df['Fuel'] == 'Gasoline')|
                                (clean_df['Fuel'] == 'Diesel')|
                                (clean_df['Fuel'] == 'Hybrid')|
                                (clean_df['Fuel'] == 'Plug-in - Hybrid')|
                                (clean_df['Fuel'] == 'Mild Hybrid')].copy()
non_electric_cars_df.drop(columns = ['Battery Range','Battery Capacity'], inplace = True)
non_electric_cars_df.shape
# Out:
# (9293, 28)

# %%
clean_df.to_csv("cars_data_cleaned.csv",index = False)

# %%
electric_cars_df.to_csv("Electric_cars_cleaned.csv",index = False)
non_electric_cars_df.to_csv("Non_Electric_cars_cleaned.csv",index = False)

# %%
electric_cars_df.isna().sum()
# Out:
# URL                   0
# Scraped_Time          0
# Condition             0
# Car Make              0
# Model                 0
# Trim                  0
# Year                  0
# Kilometers            0
# Body Type             0
# Number of Seats       0
# Fuel                  0
# Transmission          0
# Exterior Color        0
# Interior Color        0
# Regional Specs        0
# Car License           0
# Insurance             0
# Car Customs           0
# Body Condition        0
# Paint                 0
# Payment Method        0
# City                  0
# Neighborhood          0
# Interior Options      0
# Exterior Options      0
# Technology Options    0
# Price                 0
# Battery Capacity      0
# Battery Range         0
# dtype: int64

# %%
non_electric_cars_df.isna().sum()
# Out:
# URL                   0
# Scraped_Time          0
# Condition             0
# Car Make              0
# Model                 0
# Trim                  0
# Year                  0
# Kilometers            0
# Body Type             0
# Number of Seats       0
# Fuel                  0
# Transmission          0
# Engine Size (cc)      0
# Exterior Color        0
# Interior Color        0
# Regional Specs        0
# Car License           0
# Insurance             0
# Car Customs           0
# Body Condition        0
# Paint                 0
# Payment Method        0
# City                  0
# Neighborhood          0
# Interior Options      0
# Exterior Options      0
# Technology Options    0
# Price                 0
# dtype: int64
